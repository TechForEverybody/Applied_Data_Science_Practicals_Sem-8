# %% [markdown]
# ## Name: Shivkumar G. Chauhan
# ### Roll No.: CS8A53
# ### Batch A-3
# ---
# # Experiment - 6 : Explore data visualization techniques.

# %% [markdown]
# ## imports

# %%
import pandas
import numpy
import warnings
import matplotlib.pyplot as pyplot
import seaborn
import geopandas
import scipy.stats
from sklearn import preprocessing
import networkx

# %% [markdown]
# ## Configurations

# %%
StandardScaler=preprocessing.StandardScaler(
    with_mean=False,
    with_std=True
)
Normalizer=preprocessing.Normalizer(
    norm='max'
)

# %%
# %matplotlib qt
# %matplotlib inline
pyplot.rcParams["figure.figsize"] = (15, 12)

# %% [markdown]
# hiding warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# Initializing Functions

# %%
def normalDistributionGraphGenarator(
    data:numpy.array,
    *ExtraArguments
)->None:
    """Normalization graph plotter function

    Args:
        data (numpy.array): Any Array or DataFrame Column
    """
    pyplot.figure('Normal Distribution Graph')
    data=numpy.sort(data)
    pyplot.plot(data, scipy.stats.norm.pdf(
        data, 
        numpy.mean(data),
        numpy.std(data))
    )
    for data in ExtraArguments:
        data=numpy.sort(data)
        pyplot.plot(data, 
            scipy.stats.norm.pdf(
            data, 
            numpy.mean(data),
            numpy.std(data))
    )
    pyplot.xlabel('values')
    pyplot.ylabel("Normalized Values")

# %%
def generateClusters(data:pandas.DataFrame,column_name:str,number_of_clusters=5)->list:
    """ Function for getting clusters using Kmeans Method
        Only Numerical Column is allowed

    Args:
        data (pandas.DataFrame): DataFrame Copy
        column_name (str): Specific Column Name
        number_of_clusters (int, optional): number of required clusters . Defaults to 5.

    Returns:
        list: list of DataFrames
    """
    Samples=[]
    column_data=data[column_name]
    cluster_centers,_=kmeans(
        column_data.to_numpy(),
        k_or_guess=number_of_clusters
    )
    cluster_indexes,_ = vq(
        column_data.to_numpy(),
        cluster_centers
    )
    data["cluster_value"]=cluster_indexes
    for i in range(number_of_clusters):
        Samples.append(
            data[data["cluster_value"]==i].sort_values(by=column_name,
                                                       ascending=False
    ).reset_index(
                drop=True
    ).drop(
        ['cluster_value'],axis=1)
    )
    data=data.drop(['cluster_value'],axis=1)
    return Samples

# %%
def PreprocessTheCovidData(Main_Data:pandas.DataFrame,Selected_columns:list,isCumulative=False)->pandas.DataFrame:
    """Final Function for Whole Data Processing for Covid Data

    Args:
        Main_Data (pandas.DataFrame): Initial Raw Data
        Selected_columns (list): list of columns that to bet selected

    Returns:
        pandas.DataFrame: Preprocessed Data
    """
    Main_Data=Main_Data[Selected_Columns]
    if isCumulative:
        for index in Main_Data['location'].value_counts().index:
            if len(Main_Data[Main_Data['location']==index]['total_cases'].unique())<2:
                Main_Data=Main_Data[Main_Data['location']!=index]
    for index in Main_Data[Main_Data['continent'].isnull()==True]['location'].value_counts().index:
        if index.find("income")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Income Based"})
        elif index.find("Europe")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Europe"})
        elif index.find("International")!=-1 or index.find("World")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"World"})
        else:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":index})
    for index in Main_Data[Main_Data['life_expectancy'].isnull()==False]['continent'].value_counts().index:
        Main_Data[Main_Data['continent']==index]=Main_Data[Main_Data['continent']==index].fillna(value={"life_expectancy":Main_Data[Main_Data['continent']==index]['life_expectancy'].mean()})
    Main_Data=Main_Data.fillna(value={"life_expectancy":Main_Data['life_expectancy'].mean()})
    Main_Data['population']=Main_Data['population'].fillna(Main_Data[Main_Data['location']=='International']['total_cases'].max())
    Main_Data[['new_cases','new_deaths']]=Main_Data[['new_cases','new_deaths']].fillna(0)
    for index in Main_Data['location'].value_counts().index:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(0,limit=1)
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(method='ffill')
    return Main_Data

# %% [markdown]
# reading dataset

# %%
Raw_Data=pandas.read_csv("../Data/Raw_Data/owid-covid-data.csv",date_parser='date')

# %% [markdown]
# Sorting the Dataframe using total_cases column

# %% [markdown]
# selecting specific columns

# %%
Raw_Data=Raw_Data.sort_values(
    by="total_cases",
    ascending=False
).reset_index(drop=True)

# %%
Selected_Columns=['iso_code','date', 'continent', 'location', 'total_cases','new_cases', 'total_deaths', 'new_deaths','population','life_expectancy']

# %% [markdown]
# Location Specific Data

# %% [markdown]
# Recently Updated Data

# %%
location="World"

# %%
recent_date=Raw_Data['date'][0]
Recent_Data=Raw_Data[Raw_Data['date']==recent_date]

# %%
Location_Specific_Data=Raw_Data[
    Raw_Data['location']==location
]

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Raw Data

# %% [markdown]
# printing Checking of Raw dataset

# %%
Raw_Data.head()
# Out:
#    iso_code continent location        date  total_cases  new_cases  \
# 0  OWID_WRL       NaN    World  2023-02-12  672789992.0    76746.0
# 1  OWID_WRL       NaN    World  2023-02-11  672713246.0   131483.0
# 2  OWID_WRL       NaN    World  2023-02-10  672581763.0   142758.0
# 3  OWID_WRL       NaN    World  2023-02-09  672440247.0   257000.0
# 4  OWID_WRL       NaN    World  2023-02-08  672183247.0   228269.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0          168124.000     6853702.0       369.0             1247.286  ...
# 1          169768.429     6853333.0       622.0             1268.857  ...
# 2          165649.000     6852711.0      1422.0             1733.286  ...
# 3          179259.857     6851332.0      2259.0             1851.000  ...
# 4          179518.429     6849409.0      1896.0             1908.429  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0        34.635                   60.13                       2.705
# 1        34.635                   60.13                       2.705
# 2        34.635                   60.13                       2.705
# 3        34.635                   60.13                       2.705
# 4        34.635                   60.13                       2.705
#
#    life_expectancy  human_development_index    population  \
# 0            72.58                    0.737  7.975105e+09
# 1            72.58                    0.737  7.975105e+09
# 2            72.58                    0.737  7.975105e+09
# 3            72.58                    0.737  7.975105e+09
# 4            72.58                    0.737  7.975105e+09
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Raw_Data.describe(include="all")
# Out:
#        iso_code continent location        date   total_cases     new_cases  \
# count    257015    242587   257015      257015  2.425620e+05  2.422160e+05
# unique      248         6      248        1139           NaN           NaN
# top         MEX    Europe   Mexico  2021-11-09           NaN           NaN
# freq       1139     58802     1139         247           NaN           NaN
# mean        NaN       NaN      NaN         NaN  5.249953e+06  1.184319e+04
# std         NaN       NaN      NaN         NaN  3.231413e+07  8.230481e+04
# min         NaN       NaN      NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN      NaN         NaN  5.678000e+03  0.000000e+00
# 50%         NaN       NaN      NaN         NaN  6.171400e+04  3.800000e+01
# 75%         NaN       NaN      NaN         NaN  6.369140e+05  8.300000e+02
# max         NaN       NaN      NaN         NaN  6.727900e+08  4.082889e+06
#
#         new_cases_smoothed  total_deaths     new_deaths  new_deaths_smoothed  \
# count         2.410120e+05  2.229170e+05  222814.000000        221628.000000
# unique                 NaN           NaN            NaN                  NaN
# top                    NaN           NaN            NaN                  NaN
# freq                   NaN           NaN            NaN                  NaN
# mean          1.189204e+04  7.958587e+04     127.809734           128.391436
# std           8.001572e+04  4.056417e+05     739.516653           685.526668
# min           0.000000e+00  1.000000e+00       0.000000             0.000000
# 25%           4.571000e+00  1.230000e+02       0.000000             0.000000
# 50%           7.828600e+01  1.352000e+03       0.000000             1.143000
# 75%           1.012571e+03  1.094500e+04      12.000000            13.571000
# max           3.436560e+06  6.853702e+06   60788.000000         14860.286000
#
#         ...   male_smokers  handwashing_facilities  \
# count   ...  154495.000000           101880.000000
# unique  ...            NaN                     NaN
# top     ...            NaN                     NaN
# freq    ...            NaN                     NaN
# mean    ...      32.820334               50.900699
# std     ...      13.539007               31.884795
# min     ...       7.700000                1.188000
# 25%     ...      21.600000               20.859000
# 50%     ...      33.100000               49.839000
# 75%     ...      41.300000               83.241000
# max     ...      78.100000              100.000000
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                184148.000000    235807.000000            201879.000000
# unique                         NaN              NaN                      NaN
# top                            NaN              NaN                      NaN
# freq                           NaN              NaN                      NaN
# mean                      3.089301        73.596906                 0.724549
# std                       2.551590         7.446936                 0.149554
# min                       0.100000        53.280000                 0.394000
# 25%                       1.300000        69.500000                 0.602000
# 50%                       2.500000        75.050000                 0.742000
# 75%                       4.200000        79.070000                 0.838000
# max                      13.800000        86.750000                 0.957000
#
#           population  excess_mortality_cumulative_absolute  \
# count   2.559130e+05                          8.531000e+03
# unique           NaN                                   NaN
# top              NaN                                   NaN
# freq             NaN                                   NaN
# mean    1.405575e+08                          5.167216e+04
# std     6.917380e+08                          1.407291e+05
# min     4.700000e+01                         -3.772610e+04
# 25%     8.367830e+05                          8.600001e+01
# 50%     6.948395e+06                          6.983201e+03
# 75%     3.369661e+07                          3.765704e+04
# max     7.975105e+09                          1.253111e+06
#
#         excess_mortality_cumulative  excess_mortality  \
# count                   8531.000000       8531.000000
# unique                          NaN               NaN
# top                             NaN               NaN
# freq                            NaN               NaN
# mean                      10.313593         14.114181
# std                       13.242279         25.822521
# min                      -28.450000        -95.920000
# 25%                        1.045000          0.250000
# 50%                        7.970000          7.580000
# 75%                       16.310000         19.180000
# max                       76.550000        376.770000
#
#         excess_mortality_cumulative_per_million
# count                               8531.000000
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                1490.624400
# std                                 1831.869984
# min                                -1984.281600
# 25%                                   51.556450
# 50%                                  927.002100
# 75%                                 2399.098100
# max                                10112.677000
#
# [11 rows x 67 columns]

# %% [markdown]
# printing the dataset information like column values counts, column value data type

# %%
Raw_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257015 entries, 0 to 257014
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    257015 non-null  object
#  1   continent                                   242587 non-null  object
#  2   location                                    257015 non-null  object
#  3   date                                        257015 non-null  object
#  4   total_cases                                 242562 non-null  float64
#  5   new_cases                                   242216 non-null  float64
#  6   new_cases_smoothed                          241012 non-null  float64
#  7   total_deaths                                222917 non-null  float64
#  8   new_deaths                                  222814 non-null  float64
#  9   new_deaths_smoothed                         221628 non-null  float64
#  10  total_cases_per_million                     241460 non-null  float64
#  11  new_cases_per_million                       241114 non-null  float64
#  12  new_cases_smoothed_per_million              239915 non-null  float64
#  13  total_deaths_per_million                    221828 non-null  float64
#  14  new_deaths_per_million                      221725 non-null  float64
#  15  new_deaths_smoothed_per_million             220544 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                34663 non-null   float64
#  18  icu_patients_per_million                    34663 non-null   float64
#  19  hosp_patients                               37722 non-null   float64
#  20  hosp_patients_per_million                   37722 non-null   float64
#  21  weekly_icu_admissions                       8669 non-null    float64
#  22  weekly_icu_admissions_per_million           8669 non-null    float64
#  23  weekly_hosp_admissions                      20491 non-null   float64
#  24  weekly_hosp_admissions_per_million          20491 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          72074 non-null   float64
#  35  people_vaccinated                           68968 non-null   float64
#  36  people_fully_vaccinated                     66322 non-null   float64
#  37  total_boosters                              40841 non-null   float64
#  38  new_vaccinations                            59774 non-null   float64
#  39  new_vaccinations_smoothed                   152951 non-null  float64
#  40  total_vaccinations_per_hundred              72074 non-null   float64
#  41  people_vaccinated_per_hundred               68968 non-null   float64
#  42  people_fully_vaccinated_per_hundred         66322 non-null   float64
#  43  total_boosters_per_hundred                  40841 non-null   float64
#  44  new_vaccinations_smoothed_per_million       152951 non-null  float64
#  45  new_people_vaccinated_smoothed              152817 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  152817 non-null  float64
#  47  stringency_index                            185909 non-null  float64
#  48  population_density                          223935 non-null  float64
#  49  median_age                                  207119 non-null  float64
#  50  aged_65_older                               204936 non-null  float64
#  51  aged_70_older                               206036 non-null  float64
#  52  gdp_per_capita                              206778 non-null  float64
#  53  extreme_poverty                             134668 non-null  float64
#  54  cardiovasc_death_rate                       206505 non-null  float64
#  55  diabetes_prevalence                         217374 non-null  float64
#  56  female_smokers                              156638 non-null  float64
#  57  male_smokers                                154495 non-null  float64
#  58  handwashing_facilities                      101880 non-null  float64
#  59  hospital_beds_per_thousand                  184148 non-null  float64
#  60  life_expectancy                             235807 non-null  float64
#  61  human_development_index                     201879 non-null  float64
#  62  population                                  255913 non-null  float64
#  63  excess_mortality_cumulative_absolute        8531 non-null    float64
#  64  excess_mortality_cumulative                 8531 non-null    float64
#  65  excess_mortality                            8531 non-null    float64
#  66  excess_mortality_cumulative_per_million     8531 non-null    float64
# dtypes: float64(62), object(5)
# memory usage: 131.4+ MB

# %% [markdown]
# ## Location Specific Data

# %% [markdown]
# Printing Location Specific Data

# %%
Location_Specific_Data.head()
# Out:
#    iso_code continent location        date  total_cases  new_cases  \
# 0  OWID_WRL       NaN    World  2023-02-12  672789992.0    76746.0
# 1  OWID_WRL       NaN    World  2023-02-11  672713246.0   131483.0
# 2  OWID_WRL       NaN    World  2023-02-10  672581763.0   142758.0
# 3  OWID_WRL       NaN    World  2023-02-09  672440247.0   257000.0
# 4  OWID_WRL       NaN    World  2023-02-08  672183247.0   228269.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0          168124.000     6853702.0       369.0             1247.286  ...
# 1          169768.429     6853333.0       622.0             1268.857  ...
# 2          165649.000     6852711.0      1422.0             1733.286  ...
# 3          179259.857     6851332.0      2259.0             1851.000  ...
# 4          179518.429     6849409.0      1896.0             1908.429  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0        34.635                   60.13                       2.705
# 1        34.635                   60.13                       2.705
# 2        34.635                   60.13                       2.705
# 3        34.635                   60.13                       2.705
# 4        34.635                   60.13                       2.705
#
#    life_expectancy  human_development_index    population  \
# 0            72.58                    0.737  7.975105e+09
# 1            72.58                    0.737  7.975105e+09
# 2            72.58                    0.737  7.975105e+09
# 3            72.58                    0.737  7.975105e+09
# 4            72.58                    0.737  7.975105e+09
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Location_Specific_Data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.118000e+03  1.118000e+03        1.113000e+03  1.118000e+03
# mean   2.683370e+08  6.003492e+05        6.026463e+05  3.799553e+06
# std    2.348252e+08  5.935444e+05        5.682012e+05  2.421545e+06
# min    5.570000e+02  0.000000e+00        3.388570e+02  1.700000e+01
# 25%    4.416838e+07  2.798618e+05        3.083566e+05  1.238696e+06
# 50%    1.997513e+08  4.816950e+05        4.978420e+05  4.267262e+06
# 75%    5.183744e+08  6.824970e+05        6.460574e+05  6.281390e+06
# max    6.727900e+08  4.082889e+06        3.436560e+06  6.853702e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count   1118.000000          1113.000000              1118.000000
# mean    6097.053667          6121.513426             33646.828918
# std     4389.416540          3834.947046             29444.779815
# min        0.000000             9.286000                 0.070000
# 25%     2297.000000          2203.000000              5538.281750
# 50%     5902.500000          6071.429000             25046.858500
# 75%     8832.250000          9216.143000             64999.070750
# max    60788.000000         14860.286000             84361.270000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count            1118.000000                     1113.000000
# mean               75.277906                       75.565928
# std                74.424638                       71.246868
# min                 0.000000                        0.042000
# 25%                35.091750                       38.665000
# 50%                60.400000                       62.425000
# 75%                85.578000                       81.009000
# max               511.954000                      430.911000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count               1118.000000  ...  1.118000e+03            1.118000e+03
# mean                 476.426695  ...  3.463500e+01            6.013000e+01
# std                  303.638069  ...  7.108607e-15            7.108607e-15
# min                    0.002000  ...  3.463500e+01            6.013000e+01
# 25%                  155.320000  ...  3.463500e+01            6.013000e+01
# 50%                  535.073000  ...  3.463500e+01            6.013000e+01
# 75%                  787.624750  ...  3.463500e+01            6.013000e+01
# max                  859.387000  ...  3.463500e+01            6.013000e+01
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                    1118.000          1118.00             1.118000e+03
# mean                        2.705            72.58             7.370000e-01
# std                         0.000             0.00             1.110720e-16
# min                         2.705            72.58             7.370000e-01
# 25%                         2.705            72.58             7.370000e-01
# 50%                         2.705            72.58             7.370000e-01
# 75%                         2.705            72.58             7.370000e-01
# max                         2.705            72.58             7.370000e-01
#
#          population  excess_mortality_cumulative_absolute  \
# count  1.118000e+03                                   0.0
# mean   7.975105e+09                                   NaN
# std    0.000000e+00                                   NaN
# min    7.975105e+09                                   NaN
# 25%    7.975105e+09                                   NaN
# 50%    7.975105e+09                                   NaN
# 75%    7.975105e+09                                   NaN
# max    7.975105e+09                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# count                          0.0               0.0
# mean                           NaN               NaN
# std                            NaN               NaN
# min                            NaN               NaN
# 25%                            NaN               NaN
# 50%                            NaN               NaN
# 75%                            NaN               NaN
# max                            NaN               NaN
#
#        excess_mortality_cumulative_per_million
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
# [8 rows x 62 columns]

# %% [markdown]
# ## Recently Updated Data

# %% [markdown]
# Printing Recently Updated Data

# %%
Recent_Data
# Out:
#         iso_code      continent         location        date  total_cases  \
# 0       OWID_WRL            NaN            World  2023-02-12  672789992.0
# 355     OWID_HIC            NaN      High income  2023-02-12  428947809.0
# 811     OWID_EUR            NaN           Europe  2023-02-12  247078476.0
# 1134    OWID_ASI            NaN             Asia  2023-02-12  209906439.0
# 1440    OWID_EUN            NaN   European Union  2023-02-12  183299960.0
# ...          ...            ...              ...         ...          ...
# 202413       MSR  North America       Montserrat  2023-02-12       1403.0
# 208578  OWID_INT            NaN    International  2023-02-12        721.0
# 228398       VAT         Europe          Vatican  2023-02-12         29.0
# 242240       PRK           Asia      North Korea  2023-02-12          1.0
# 248698  OWID_CYN           Asia  Northern Cyprus  2023-02-12          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0         76746.0          168124.000     6853702.0       369.0
# 355       57908.0          140305.143     2855457.0       257.0
# 811       21757.0           45771.714     2027034.0        51.0
# 1134      38544.0           65275.571     1619549.0       248.0
# 1440       8336.0           30078.000     1210060.0        14.0
# ...           ...                 ...           ...         ...
# 202413        0.0               0.000           8.0         0.0
# 208578        0.0               0.000          15.0         0.0
# 228398        0.0               0.000           NaN         NaN
# 242240        0.0               0.000           6.0         0.0
# 248698        NaN                 NaN           NaN         NaN
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 0                  1247.286  ...        34.635                   60.13
# 355                1065.857  ...           NaN                     NaN
# 811                 384.714  ...           NaN                     NaN
# 1134                286.286  ...           NaN                     NaN
# 1440                280.571  ...           NaN                     NaN
# ...                     ...  ...           ...                     ...
# 202413                0.000  ...           NaN                     NaN
# 208578                0.000  ...           NaN                     NaN
# 228398                  NaN  ...           NaN                     NaN
# 242240                0.000  ...           NaN                     NaN
# 248698                  NaN  ...           NaN                     NaN
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                            2.705            72.58                    0.737
# 355                            NaN              NaN                      NaN
# 811                            NaN              NaN                      NaN
# 1134                           NaN              NaN                      NaN
# 1440                           NaN              NaN                      NaN
# ...                            ...              ...                      ...
# 202413                         NaN            74.16                      NaN
# 208578                         NaN              NaN                      NaN
# 228398                         NaN            75.12                      NaN
# 242240                      13.200            72.27                      NaN
# 248698                         NaN              NaN                      NaN
#
#           population  excess_mortality_cumulative_absolute  \
# 0       7.975105e+09                                   NaN
# 355     1.250515e+09                                   NaN
# 811     7.448078e+08                                   NaN
# 1134    4.721383e+09                                   NaN
# 1440    4.501468e+08                                   NaN
# ...              ...                                   ...
# 202413  4.413000e+03                                   NaN
# 208578           NaN                                   NaN
# 228398  8.080000e+02                                   NaN
# 242240  2.606942e+07                                   NaN
# 248698  3.828360e+05                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 355                             NaN               NaN
# 811                             NaN               NaN
# 1134                            NaN               NaN
# 1440                            NaN               NaN
# ...                             ...               ...
# 202413                          NaN               NaN
# 208578                          NaN               NaN
# 228398                          NaN               NaN
# 242240                          NaN               NaN
# 248698                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 355                                         NaN
# 811                                         NaN
# 1134                                        NaN
# 1440                                        NaN
# ...                                         ...
# 202413                                      NaN
# 208578                                      NaN
# 228398                                      NaN
# 242240                                      NaN
# 248698                                      NaN
#
# [232 rows x 67 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Recent_Data.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.310000e+02    188.000000          188.000000  2.270000e+02
# mean   1.244339e+07   1677.234043         3556.424761  1.261003e+05
# std    5.941804e+07   7994.240279        17628.446516  5.773880e+05
# min    1.000000e+00      0.000000            0.000000  1.000000e+00
# 25%    3.215250e+04      0.000000            0.000000  2.975000e+02
# 50%    2.868670e+05      0.000000            1.286000  3.164000e+03
# 75%    2.196799e+06     41.000000           46.500250  2.138400e+04
# max    6.727900e+08  76746.000000       168124.000000  6.853702e+06
#
#        new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  208.000000           208.000000               230.000000
# mean     7.163462            23.746577            186885.415526
# std     37.464859           126.375969            190865.434408
# min      0.000000             0.000000                 0.038000
# 25%      0.000000             0.000000             16364.635000
# 50%      0.000000             0.000000            122721.342500
# 75%      0.000000             0.571000            313389.849000
# max    369.000000          1247.286000            720435.220000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count             187.000000                      187.000000
# mean               24.257273                       24.545460
# std               144.432690                       84.151325
# min                 0.000000                        0.000000
# 25%                 0.000000                        0.000000
# 50%                 0.000000                        0.171000
# 75%                 1.089500                       12.369500
# max              1613.025000                      838.564000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count                226.000000  ...    145.000000               95.000000
# mean                1255.897407  ...     32.909897               50.270832
# std                 1288.606480  ...     13.621757               31.889658
# min                    0.230000  ...      7.700000                1.188000
# 25%                  169.466500  ...     22.600000               20.105000
# 50%                  787.118000  ...     33.100000               49.542000
# 75%                 2023.891500  ...     41.300000               81.568500
# max                 6439.696000  ...     78.100000               98.999000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                  172.000000       218.000000               189.000000
# mean                     3.071994        73.393440                 0.722540
# std                      2.541906         7.482858                 0.149793
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        68.532500                 0.602000
# 50%                      2.450000        74.705000                 0.740000
# 75%                      4.050000        78.875000                 0.829000
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  2.310000e+02                                   0.0
# mean   1.398762e+08                                   NaN
# std    6.903625e+08                                   NaN
# min    8.080000e+02                                   NaN
# 25%    8.227550e+05                                   NaN
# 50%    7.488863e+06                                   NaN
# 75%    3.358624e+07                                   NaN
# max    7.975105e+09                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# count                          0.0               0.0
# mean                           NaN               NaN
# std                            NaN               NaN
# min                            NaN               NaN
# 25%                            NaN               NaN
# 50%                            NaN               NaN
# 75%                            NaN               NaN
# max                            NaN               NaN
#
#        excess_mortality_cumulative_per_million
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
# [8 rows x 62 columns]

# %%
Recent_Data.copy().reset_index()
# Out:
#       index  iso_code      continent         location        date  \
# 0         0  OWID_WRL            NaN            World  2023-02-12
# 1       355  OWID_HIC            NaN      High income  2023-02-12
# 2       811  OWID_EUR            NaN           Europe  2023-02-12
# 3      1134  OWID_ASI            NaN             Asia  2023-02-12
# 4      1440  OWID_EUN            NaN   European Union  2023-02-12
# ..      ...       ...            ...              ...         ...
# 227  202413       MSR  North America       Montserrat  2023-02-12
# 228  208578  OWID_INT            NaN    International  2023-02-12
# 229  228398       VAT         Europe          Vatican  2023-02-12
# 230  242240       PRK           Asia      North Korea  2023-02-12
# 231  248698  OWID_CYN           Asia  Northern Cyprus  2023-02-12
#
#      total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0    672789992.0    76746.0          168124.000     6853702.0       369.0
# 1    428947809.0    57908.0          140305.143     2855457.0       257.0
# 2    247078476.0    21757.0           45771.714     2027034.0        51.0
# 3    209906439.0    38544.0           65275.571     1619549.0       248.0
# 4    183299960.0     8336.0           30078.000     1210060.0        14.0
# ..           ...        ...                 ...           ...         ...
# 227       1403.0        0.0               0.000           8.0         0.0
# 228        721.0        0.0               0.000          15.0         0.0
# 229         29.0        0.0               0.000           NaN         NaN
# 230          1.0        0.0               0.000           6.0         0.0
# 231          NaN        NaN                 NaN           NaN         NaN
#
#      ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0    ...        34.635                   60.13                       2.705
# 1    ...           NaN                     NaN                         NaN
# 2    ...           NaN                     NaN                         NaN
# 3    ...           NaN                     NaN                         NaN
# 4    ...           NaN                     NaN                         NaN
# ..   ...           ...                     ...                         ...
# 227  ...           NaN                     NaN                         NaN
# 228  ...           NaN                     NaN                         NaN
# 229  ...           NaN                     NaN                         NaN
# 230  ...           NaN                     NaN                      13.200
# 231  ...           NaN                     NaN                         NaN
#
#      life_expectancy  human_development_index    population  \
# 0              72.58                    0.737  7.975105e+09
# 1                NaN                      NaN  1.250515e+09
# 2                NaN                      NaN  7.448078e+08
# 3                NaN                      NaN  4.721383e+09
# 4                NaN                      NaN  4.501468e+08
# ..               ...                      ...           ...
# 227            74.16                      NaN  4.413000e+03
# 228              NaN                      NaN           NaN
# 229            75.12                      NaN  8.080000e+02
# 230            72.27                      NaN  2.606942e+07
# 231              NaN                      NaN  3.828360e+05
#
#      excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ..                                    ...                          ...
# 227                                   NaN                          NaN
# 228                                   NaN                          NaN
# 229                                   NaN                          NaN
# 230                                   NaN                          NaN
# 231                                   NaN                          NaN
#
#      excess_mortality  excess_mortality_cumulative_per_million
# 0                 NaN                                      NaN
# 1                 NaN                                      NaN
# 2                 NaN                                      NaN
# 3                 NaN                                      NaN
# 4                 NaN                                      NaN
# ..                ...                                      ...
# 227               NaN                                      NaN
# 228               NaN                                      NaN
# 229               NaN                                      NaN
# 230               NaN                                      NaN
# 231               NaN                                      NaN
#
# [232 rows x 68 columns]

# %% [markdown]
# # Data Preprocessing

# %%
Main_Data=PreprocessTheCovidData(
    Location_Specific_Data.copy().sort_values(by='date',ascending=True).reset_index(drop=True),
    Selected_Columns
)

# %%
Main_Data
# Out:
#       iso_code        date continent location  total_cases  new_cases  \
# 0     OWID_WRL  2020-01-22     World    World        557.0        0.0
# 1     OWID_WRL  2020-01-23     World    World        657.0      100.0
# 2     OWID_WRL  2020-01-24     World    World        944.0      287.0
# 3     OWID_WRL  2020-01-25     World    World       1437.0      493.0
# 4     OWID_WRL  2020-01-26     World    World       2120.0      683.0
# ...        ...         ...       ...      ...          ...        ...
# 1113  OWID_WRL  2023-02-08     World    World  672183247.0   228269.0
# 1114  OWID_WRL  2023-02-09     World    World  672440247.0   257000.0
# 1115  OWID_WRL  2023-02-10     World    World  672581763.0   142758.0
# 1116  OWID_WRL  2023-02-11     World    World  672713246.0   131483.0
# 1117  OWID_WRL  2023-02-12     World    World  672789992.0    76746.0
#
#       total_deaths  new_deaths    population  life_expectancy
# 0             17.0         0.0  7.975105e+09            72.58
# 1             18.0         1.0  7.975105e+09            72.58
# 2             26.0         8.0  7.975105e+09            72.58
# 3             42.0        16.0  7.975105e+09            72.58
# 4             56.0        14.0  7.975105e+09            72.58
# ...            ...         ...           ...              ...
# 1113     6849409.0      1896.0  7.975105e+09            72.58
# 1114     6851332.0      2259.0  7.975105e+09            72.58
# 1115     6852711.0      1422.0  7.975105e+09            72.58
# 1116     6853333.0       622.0  7.975105e+09            72.58
# 1117     6853702.0       369.0  7.975105e+09            72.58
#
# [1118 rows x 10 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Basic and Most used Graphs

# %% [markdown]
# ### Normal Distribution Graphs Ploting

# %%
normalDistributionGraphGenarator(Main_Data['total_cases'])

# %%
normalDistributionGraphGenarator(Main_Data['total_deaths'])

# %%
normalDistributionGraphGenarator(Main_Data['new_cases'])

# %%
normalDistributionGraphGenarator(Main_Data['population'])

# %%
normalDistributionGraphGenarator(Main_Data['new_deaths'])

# %%
normalDistributionGraphGenarator(Main_Data['life_expectancy'])

# %% [markdown]
# ### Line Graphs

# %%
Main_Data.plot(x='date', y='total_cases')
# Out:
# <AxesSubplot: xlabel='date'>

# %%
Main_Data.plot(x='date', y='total_deaths')
# Out:
# <AxesSubplot: xlabel='date'>

# %%
Main_Data.plot(x='date', y='new_cases')
# Out:
# <AxesSubplot: xlabel='date'>

# %%
Main_Data.plot(x='date', y='new_deaths')
# Out:
# <AxesSubplot: xlabel='date'>

# %%
Main_Data.plot(x='date', y=['new_cases','new_deaths'])
# Out:
# <AxesSubplot: xlabel='date'>

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# ### Box Plot

# %%
Main_Data.boxplot('population')
# Out:
# <AxesSubplot: >

# %%
Main_Data.boxplot('total_cases')
# Out:
# <AxesSubplot: >

# %%
Main_Data.boxplot('new_deaths')
# Out:
# <AxesSubplot: >

# %%
Main_Data.boxplot('total_deaths')
# Out:
# <AxesSubplot: >

# %%
Main_Data.boxplot('new_cases')
# Out:
# <AxesSubplot: >

# %%
Main_Data.boxplot('life_expectancy')
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Violin Plots

# %%
seaborn.violinplot(Main_Data['total_cases'])
# Out:
# <AxesSubplot: >

# %%
seaborn.violinplot(Main_Data['total_deaths'])
# Out:
# <AxesSubplot: >

# %%
seaborn.violinplot(Main_Data['new_deaths'])
# Out:
# <AxesSubplot: >

# %%
seaborn.violinplot(Main_Data['new_cases'])
# Out:
# <AxesSubplot: >

# %%
seaborn.violinplot(Main_Data['population'])
# Out:
# <AxesSubplot: >

# %%
seaborn.violinplot(Main_Data['life_expectancy'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Scatter Plots

# %%
Main_Data[:10].plot.scatter(x='date',y='population')
# Out:
# <AxesSubplot: xlabel='date', ylabel='population'>

# %%
Main_Data[:10].plot.scatter(x='date',y='life_expectancy')
# Out:
# <AxesSubplot: xlabel='date', ylabel='life_expectancy'>

# %%
pyplot.scatter(
    Main_Data[:20]['date'],
    Main_Data[:20]['new_cases']
)
pyplot.scatter(
    Main_Data[:20]['date'],
    Main_Data[:20]['new_deaths']
)
pyplot.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plotter = pyplot.subplot(projection='3d')
plotter.scatter3D(Main_Data['total_deaths'],Main_Data['new_cases'],Main_Data['new_deaths'])
plotter.set_xlabel('total_deaths')
plotter.set_ylabel('new_cases')
plotter.set_zlabel('new_deaths')
plotter.view_init(0, 250)

# %% [markdown]
# ### Area charts

# %% [markdown]
# ### Bar Charts

# %% [markdown]
# ### Histograms

# %% [markdown]
# ### Stem and Leaf Plot

# %% [markdown]
# ## Extras

# %% [markdown]
# ### Venn Diagrams

# %% [markdown]
# ### Network Graph

# %% [markdown]
# ### Radar Chart

# %% [markdown]
# ### Geographical Maps

# %% [markdown]
# ## Tree Maps

# %%
Main_Data
# Out:
#       iso_code        date continent location  total_cases  new_cases  \
# 0     OWID_WRL  2020-01-22     World    World        557.0        0.0
# 1     OWID_WRL  2020-01-23     World    World        657.0      100.0
# 2     OWID_WRL  2020-01-24     World    World        944.0      287.0
# 3     OWID_WRL  2020-01-25     World    World       1437.0      493.0
# 4     OWID_WRL  2020-01-26     World    World       2120.0      683.0
# ...        ...         ...       ...      ...          ...        ...
# 1113  OWID_WRL  2023-02-08     World    World  672183247.0   228269.0
# 1114  OWID_WRL  2023-02-09     World    World  672440247.0   257000.0
# 1115  OWID_WRL  2023-02-10     World    World  672581763.0   142758.0
# 1116  OWID_WRL  2023-02-11     World    World  672713246.0   131483.0
# 1117  OWID_WRL  2023-02-12     World    World  672789992.0    76746.0
#
#       total_deaths  new_deaths    population  life_expectancy
# 0             17.0         0.0  7.975105e+09            72.58
# 1             18.0         1.0  7.975105e+09            72.58
# 2             26.0         8.0  7.975105e+09            72.58
# 3             42.0        16.0  7.975105e+09            72.58
# 4             56.0        14.0  7.975105e+09            72.58
# ...            ...         ...           ...              ...
# 1113     6849409.0      1896.0  7.975105e+09            72.58
# 1114     6851332.0      2259.0  7.975105e+09            72.58
# 1115     6852711.0      1422.0  7.975105e+09            72.58
# 1116     6853333.0       622.0  7.975105e+09            72.58
# 1117     6853702.0       369.0  7.975105e+09            72.58
#
# [1118 rows x 10 columns]

# %% [markdown]
# # References

# %% [markdown]
# ###### Other Data Resources:
# https://www.kaggle.com/datasets/nehaprabhavalkar/india-gis-data
