# %% [markdown]
# ## Name: Shivkumar G. Chauhan
# ### Roll No.: CS8A53
# ### Batch A-3
# ---
# # Experiment - 2 : Explore different Sampling Techniques

# %% [markdown]
# ## imports

# %%
import pandas
import numpy
import statistics
import scipy.stats
import matplotlib.pyplot as pyplot
import warnings
import random
from scipy.cluster.vq import kmeans, vq

# %% [markdown]
# ## Configurations

# %% [markdown]
# initializing matplotlib configurations

# %% [markdown]
# hiding warnings

# %%
# %matplotlib qt
# %matplotlib inline
pyplot.rcParams["figure.figsize"] = (15, 12)

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# initialization of functions

# %%
def generateClusters(data:pandas.DataFrame,column_name:str,number_of_clusters=5)->list:
    """ Function for getting clusters using Kmeans Method
        Only Numerical Column is allowed

    Args:
        data (pandas.DataFrame): DataFrame Copy
        column_name (str): Specific Column Name
        number_of_clusters (int, optional): number of required clusters . Defaults to 5.

    Returns:
        list: list of DataFrames
    """
    Samples=[]
    column_data=data[column_name]
    cluster_centers,_=kmeans(
        column_data.to_numpy(),
        k_or_guess=number_of_clusters
    )
    cluster_indexes,_ = vq(
        column_data.to_numpy(),
        cluster_centers
    )
    data["cluster_value"]=cluster_indexes
    for i in range(number_of_clusters):
        Samples.append(
            data[data["cluster_value"]==i].sort_values(by=column_name,
                                                       ascending=False
    ).reset_index(
                drop=True
    ).drop(
        ['cluster_value'],axis=1)
    )
    data=data.drop(['cluster_value'],axis=1)
    return Samples

# %%
def generateSystematicSamples(
    data:pandas.DataFrame,
    column_name:str,number_of_samples=3,
    number_of_interval_for_selection=2
)-> list:
    """Function for getting Systematic Intervaled samples

    Args:
        data (pandas.DataFrame): DataFrame Copy
        column_name (str): Specific Column Name
        number_of_samples (int, optional): number of required samples. Defaults to 3.
        number_of_interval_for_selection (int, optional): interval between rows. Defaults to 2.

    Returns:
        list: list of DataFrames
    """
    Samples=[]
    data=data.sort_values(
        by=column_name,
        ascending=False
    ).reset_index(drop=True)
    for i in range(number_of_samples):
        Samples.append(
            data[
                i::number_of_interval_for_selection
            ].sort_values(
                by=column_name,
                ascending=False
            ).reset_index(drop=True)
        )
    return Samples

# %% [markdown]
# reading dataset

# %%
Data=pandas.read_csv("../Data/Raw_Data/24_01_2023_WorldWide.csv")

# %% [markdown]
# selecting specific columns

# %%
Selected_Columns=['iso_code', 'continent', 'location', 'last_updated_date', 'total_cases', 'new_cases', 'total_deaths', 'new_deaths', 'population']

# %%
Data=Data[Selected_Columns]

# %% [markdown]
# Sorting the Dataframe using total_cases column

# %%
Data=Data.sort_values(by="total_cases",ascending=False).reset_index(drop=True)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# printing the data table

# %%
Data.head()
# Out:
#    iso_code      continent       location last_updated_date  total_cases  \
# 7       USA  North America  United States        2023-01-22  102005805.0
# 10      IND           Asia          India        2023-01-22   44683239.0
# 11      FRA         Europe         France        2023-01-22   39516793.0
# 12      DEU         Europe        Germany        2023-01-23   37668384.0
# 13      BRA  South America         Brazil        2023-01-22   36718053.0
#
#     new_cases  total_deaths  new_deaths    population
# 7      2715.0     1104118.0        15.0  3.382899e+08
# 10       94.0      530735.0         2.0  1.417173e+09
# 11     4475.0      163821.0        44.0  6.781300e+07
# 12     8866.0      164703.0       118.0  8.336984e+07
# 13      552.0      696257.0         3.0  2.153135e+08

# %% [markdown]
# printing the dataset information like column values counts, column value data type

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   iso_code           237 non-null    object
#  1   continent          224 non-null    object
#  2   location           237 non-null    object
#  3   last_updated_date  237 non-null    object
#  4   total_cases        231 non-null    float64
#  5   new_cases          231 non-null    float64
#  6   total_deaths       227 non-null    float64
#  7   new_deaths         227 non-null    float64
#  8   population         236 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 16.8+ KB

# %%
Data.describe()
# Out:
#         total_cases      new_cases  total_deaths   new_deaths    population
# count  2.310000e+02     231.000000  2.270000e+02   227.000000  2.360000e+02
# mean   1.237045e+07    2756.844156  1.240378e+05    27.453744  1.371974e+08
# std    5.904509e+07   13233.706619  5.678231e+05   120.947774  6.832297e+08
# min    1.000000e+00       0.000000  1.000000e+00     0.000000  8.080000e+02
# 25%    3.212350e+04       0.000000  2.975000e+02     0.000000  8.297690e+05
# 50%    2.859580e+05       0.000000  3.164000e+03     0.000000  6.909971e+06
# 75%    2.174932e+06     313.500000  2.049000e+04     2.000000  3.353106e+07
# max    6.687334e+08  113854.000000  6.738373e+06  1377.000000  7.975105e+09

# %%
Data.describe(include="all")
# Out:
#         iso_code continent location last_updated_date   total_cases  \
# count        237       224      237               237  2.310000e+02
# unique       237         6      237                 6           NaN
# top     OWID_WRL    Africa    World        2023-01-22           NaN
# freq           1        55        1               225           NaN
# mean         NaN       NaN      NaN               NaN  1.237045e+07
# std          NaN       NaN      NaN               NaN  5.904509e+07
# min          NaN       NaN      NaN               NaN  1.000000e+00
# 25%          NaN       NaN      NaN               NaN  3.212350e+04
# 50%          NaN       NaN      NaN               NaN  2.859580e+05
# 75%          NaN       NaN      NaN               NaN  2.174932e+06
# max          NaN       NaN      NaN               NaN  6.687334e+08
#
#             new_cases  total_deaths   new_deaths    population
# count      231.000000  2.270000e+02   227.000000  2.360000e+02
# unique            NaN           NaN          NaN           NaN
# top               NaN           NaN          NaN           NaN
# freq              NaN           NaN          NaN           NaN
# mean      2756.844156  1.240378e+05    27.453744  1.371974e+08
# std      13233.706619  5.678231e+05   120.947774  6.832297e+08
# min          0.000000  1.000000e+00     0.000000  8.080000e+02
# 25%          0.000000  2.975000e+02     0.000000  8.297690e+05
# 50%          0.000000  3.164000e+03     0.000000  6.909971e+06
# 75%        313.500000  2.049000e+04     2.000000  3.353106e+07
# max     113854.000000  6.738373e+06  1377.000000  7.975105e+09

# %% [markdown]
# ### Data Reduction

# %% [markdown]
# here some countries have NULL Values in their specific columns, so dropping the columns without filling it

# %% [markdown]
# checking if any column has null values

# %% [markdown]
# checking counts of the null values of columns

# %%
Data.isnull().any()
# Out:
# iso_code             False
# continent             True
# location             False
# last_updated_date    False
# total_cases           True
# new_cases             True
# total_deaths          True
# new_deaths            True
# population            True
# dtype: bool

# %%
Data.isnull().sum()
# Out:
# iso_code              0
# continent            13
# location              0
# last_updated_date     0
# total_cases           6
# new_cases             6
# total_deaths         10
# new_deaths           10
# population            1
# dtype: int64

# %% [markdown]
# dropping the rows that have null values

# %%
Data=Data.dropna()

# %% [markdown]
# reprinting the dataset

# %%
Data
# Out:
#     iso_code      continent                   location last_updated_date  \
# 7        USA  North America              United States        2023-01-22
# 10       IND           Asia                      India        2023-01-22
# 11       FRA         Europe                     France        2023-01-22
# 12       DEU         Europe                    Germany        2023-01-23
# 13       BRA  South America                     Brazil        2023-01-22
# ..       ...            ...                        ...               ...
# 221      MAC           Asia                      Macao        2023-01-22
# 222      WLF        Oceania          Wallis and Futuna        2023-01-22
# 223      SPM  North America  Saint Pierre and Miquelon        2023-01-22
# 227      MSR  North America                 Montserrat        2023-01-22
# 230      PRK           Asia                North Korea        2023-01-22
#
#      total_cases  new_cases  total_deaths  new_deaths    population
# 7    102005805.0     2715.0     1104118.0        15.0  3.382899e+08
# 10    44683239.0       94.0      530735.0         2.0  1.417173e+09
# 11    39516793.0     4475.0      163821.0        44.0  6.781300e+07
# 12    37668384.0     8866.0      164703.0       118.0  8.336984e+07
# 13    36718053.0      552.0      696257.0         3.0  2.153135e+08
# ..           ...        ...           ...         ...           ...
# 221       3468.0        6.0         117.0         1.0  6.951800e+05
# 222       3427.0        0.0           7.0         0.0  1.159600e+04
# 223       3411.0        0.0           2.0         0.0  5.885000e+03
# 227       1403.0        0.0           8.0         0.0  4.413000e+03
# 230          1.0        0.0           6.0         0.0  2.606942e+07
#
# [214 rows x 9 columns]

# %% [markdown]
# # Sampling

# %% [markdown]
# ## 1. Random Sampling

# %% [markdown]
# ### Random Values from Array

# %% [markdown]
# #### random indexes from array using numpy module

# %% [markdown]
# #### random indexes from array using random module

# %%
array=Data.index

# %%
numpy.random.choice(array,size=50)
# Out:
# array([207, 124, 104,  30, 144, 114,  56,   7, 187, 174, 111, 227, 110,
#         82,  41,  83,  26, 173,  11,  97, 159,  44, 182,  39,  49,  98,
#         95, 127, 154,  24, 227,  53, 100, 221, 152, 164, 138, 166,  51,
#        213, 195,  69,  80, 209, 140,  38, 191,  27, 111,  93], dtype=int64)

# %%
numpy.array(random.sample(list(array),50))
# Out:
# array([ 83,  24, 126,  94, 142, 175, 192,  70,  81,  53, 210, 134,  48,
#        199,  44,  62,  90, 144,  76, 223,  98, 183, 193,  41,  64, 107,
#        145,  74,  33, 125, 203, 170,  46, 162, 121, 188, 113, 220,  59,
#        190, 163, 115, 165, 112, 168, 166, 171,  63, 216, 179])

# %% [markdown]
# ### Random sample from whole data containing 25 % of rows

# %%
random_sample1=Data.sample(frac=0.25,replace=True).reset_index(drop=True)
print("Sample Size: ",len(random_sample1))
display(random_sample1.head(5))
# Out:
# Sample Size:  54
#   iso_code      continent    location last_updated_date  total_cases  \
# 0      BHS  North America     Bahamas        2023-01-22      37491.0
# 1      UGA         Africa      Uganda        2023-01-22     170279.0
# 2      KAZ           Asia  Kazakhstan        2023-01-22    1495880.0
# 3      NOR         Europe      Norway        2023-01-22    1477383.0
# 4      ROU         Europe     Romania        2023-01-22    3319680.0
#
#    new_cases  total_deaths  new_deaths  population
# 0        0.0         833.0         0.0    409989.0
# 1        0.0        3630.0         0.0  47249588.0
# 2      114.0       19065.0         0.0  19397998.0
# 3       26.0        5036.0        73.0   5434324.0
# 4     3488.0       67504.0        44.0  19659270.0

# %% [markdown]
# ## 2. Cluster Sampling

# %% [markdown]
# ### Sampling using KMeans

# %% [markdown]
# #### Sampling bases on new_cases column

# %%
print("Clusters Based on new_cases column")
samples=generateClusters(Data.copy(),'new_cases',2)
print("Number of Samples: ",len(samples))
for sample in samples:
    print("Sample Size: ",len(sample),"Rows")
    display(sample.head(5))
    print("\n")
# Out:
# Clusters Based on new_cases column
# Number of Samples:  2
# Sample Size:  208 Rows
#   iso_code      continent     location last_updated_date  total_cases  \
# 0      KOR           Asia  South Korea        2023-01-22   30008756.0
# 1      DEU         Europe      Germany        2023-01-23   37668384.0
# 2      AUS        Oceania    Australia        2023-01-22   11274262.0
# 3      ECU  South America      Ecuador        2023-01-22    1047624.0
# 4      CRI  North America   Costa Rica        2023-01-22    1177514.0
#
#    new_cases  total_deaths  new_deaths  population
# 0     9227.0       33235.0        26.0  51815808.0
# 1     8866.0      164703.0       118.0  83369840.0
# 2     8805.0       18092.0        69.0  26177410.0
# 3     7161.0       35940.0         0.0  18001002.0
# 4     5712.0        9123.0        19.0   5180836.0
# Sample Size:  6 Rows
#   iso_code      continent        location last_updated_date  total_cases  \
# 0      JPN           Asia           Japan        2023-01-22   32067470.0
# 1      ITA         Europe           Italy        2023-01-22   25415630.0
# 2      ARG  South America       Argentina        2023-01-22   10024095.0
# 3      TWN           Asia          Taiwan        2023-01-22    9342958.0
# 4      GBR         Europe  United Kingdom        2023-01-22   24259240.0
#
#    new_cases  total_deaths  new_deaths   population
# 0    64450.0       65377.0       326.0  123951696.0
# 1    51888.0      186488.0       495.0   59037472.0
# 2    19416.0      130338.0        89.0   45510324.0
# 3    19187.0       16098.0        27.0   23893396.0
# 4    15847.0      216255.0      1377.0   67508936.0

# %% [markdown]
# #### Sampling bases on total_cases column

# %%
print("Clusters Based on total_cases column")
samples=generateClusters(Data.copy(),'total_cases',2)
print("Number of Samples: ",len(samples))
for sample in samples:
    print("Sample Size: ",len(sample),"Rows")
    display(sample.head(10))
    print("\n")
# Out:
# Clusters Based on total_cases column
# Number of Samples:  2
# Sample Size:  204 Rows
#   iso_code      continent     location last_updated_date  total_cases  \
# 0      TUR           Asia       Turkey        2023-01-22   17042722.0
# 1      ESP         Europe        Spain        2023-01-22   13722677.0
# 2      VNM           Asia      Vietnam        2023-01-22   11526329.0
# 3      AUS        Oceania    Australia        2023-01-22   11274262.0
# 4      ARG  South America    Argentina        2023-01-22   10024095.0
# 5      TWN           Asia       Taiwan        2023-01-22    9342958.0
# 6      NLD         Europe  Netherlands        2023-01-23    8590602.0
# 7      IRN           Asia         Iran        2023-01-22    7563385.0
# 8      MEX  North America       Mexico        2023-01-22    7342277.0
# 9      IDN           Asia    Indonesia        2023-01-22    6728065.0
#
#    new_cases  total_deaths  new_deaths   population
# 0        0.0      101492.0         0.0   85341248.0
# 1    11426.0      118183.0       424.0   47558632.0
# 2       11.0       43186.0         0.0   98186856.0
# 3     8805.0       18092.0        69.0   26177410.0
# 4    19416.0      130338.0        89.0   45510324.0
# 5    19187.0       16098.0        27.0   23893396.0
# 6      913.0       23079.0         0.0   17564020.0
# 7      112.0      144735.0         1.0   88550568.0
# 8      797.0      331881.0        11.0  127504120.0
# 9      218.0      160781.0         4.0  275501344.0
# Sample Size:  10 Rows
#   iso_code      continent        location last_updated_date  total_cases  \
# 0      USA  North America   United States        2023-01-22  102005805.0
# 1      IND           Asia           India        2023-01-22   44683239.0
# 2      FRA         Europe          France        2023-01-22   39516793.0
# 3      DEU         Europe         Germany        2023-01-23   37668384.0
# 4      BRA  South America          Brazil        2023-01-22   36718053.0
# 5      JPN           Asia           Japan        2023-01-22   32067470.0
# 6      KOR           Asia     South Korea        2023-01-22   30008756.0
# 7      ITA         Europe           Italy        2023-01-22   25415630.0
# 8      GBR         Europe  United Kingdom        2023-01-22   24259240.0
# 9      RUS         Europe          Russia        2023-01-23   21585328.0
#
#    new_cases  total_deaths  new_deaths    population
# 0     2715.0     1104118.0        15.0  3.382899e+08
# 1       94.0      530735.0         2.0  1.417173e+09
# 2     4475.0      163821.0        44.0  6.781300e+07
# 3     8866.0      164703.0       118.0  8.336984e+07
# 4      552.0      696257.0         3.0  2.153135e+08
# 5    64450.0       65377.0       326.0  1.239517e+08
# 6     9227.0       33235.0        26.0  5.181581e+07
# 7    51888.0      186488.0       495.0  5.903747e+07
# 8    15847.0      216255.0      1377.0  6.750894e+07
# 9     5691.0      386748.0        40.0  1.447133e+08

# %% [markdown]
# #### Sampling bases on population column

# %%
print("Clusters Based on population column")
samples=generateClusters(Data.copy(),'population',3)
print("Number of Samples: ",len(samples))
for sample in samples:
    print("Sample Size: ",len(sample),"Rows")
    display(sample.head(10))
    print("\n")
# Out:
# Clusters Based on population column
# Number of Samples:  3
# Sample Size:  2 Rows
#   iso_code continent location last_updated_date  total_cases  new_cases  \
# 0      CHN      Asia    China        2023-01-22    2023904.0        0.0
# 1      IND      Asia    India        2023-01-22   44683239.0       94.0
#
#    total_deaths  new_deaths    population
# 0        5273.0         0.0  1.425887e+09
# 1      530735.0         2.0  1.417173e+09
# Sample Size:  17 Rows
#   iso_code      continent       location last_updated_date  total_cases  \
# 0      USA  North America  United States        2023-01-22  102005805.0
# 1      IDN           Asia      Indonesia        2023-01-22    6728065.0
# 2      PAK           Asia       Pakistan        2023-01-22    1576185.0
# 3      NGA         Africa        Nigeria        2023-01-22     266463.0
# 4      BRA  South America         Brazil        2023-01-22   36718053.0
# 5      BGD           Asia     Bangladesh        2023-01-22    2037408.0
# 6      RUS         Europe         Russia        2023-01-23   21585328.0
# 7      MEX  North America         Mexico        2023-01-22    7342277.0
# 8      JPN           Asia          Japan        2023-01-22   32067470.0
# 9      ETH         Africa       Ethiopia        2023-01-22     499306.0
#
#    new_cases  total_deaths  new_deaths   population
# 0     2715.0     1104118.0        15.0  338289856.0
# 1      218.0      160781.0         4.0  275501344.0
# 2       38.0       30640.0         0.0  235824864.0
# 3        0.0        3155.0         0.0  218541216.0
# 4      552.0      696257.0         3.0  215313504.0
# 5        0.0       29441.0         0.0  171186368.0
# 6     5691.0      386748.0        40.0  144713312.0
# 7      797.0      331881.0        11.0  127504120.0
# 8    64450.0       65377.0       326.0  123951696.0
# 9       11.0        7572.0         0.0  123379928.0
# Sample Size:  195 Rows
#   iso_code      continent        location last_updated_date  total_cases  \
# 0      THA           Asia        Thailand        2023-01-22    4725885.0
# 1      FRA         Europe          France        2023-01-22   39516793.0
# 2      GBR         Europe  United Kingdom        2023-01-22   24259240.0
# 3      TZA         Africa        Tanzania        2023-01-22      42530.0
# 4      ZAF         Africa    South Africa        2023-01-22    4054160.0
# 5      ITA         Europe           Italy        2023-01-22   25415630.0
# 6      MMR           Asia         Myanmar        2023-01-22     633801.0
# 7      KEN         Africa           Kenya        2023-01-22     342785.0
# 8      COL  South America        Colombia        2023-01-22    6348356.0
# 9      KOR           Asia     South Korea        2023-01-22   30008756.0
#
#    new_cases  total_deaths  new_deaths  population
# 0        0.0       33792.0         0.0  71697024.0
# 1     4475.0      163821.0        44.0  67813000.0
# 2    15847.0      216255.0      1377.0  67508936.0
# 3        0.0         846.0         0.0  65497752.0
# 4      364.0      102588.0        20.0  59893884.0
# 5    51888.0      186488.0       495.0  59037472.0
# 6        2.0       19490.0         0.0  54179312.0
# 7        3.0        5688.0         0.0  54027484.0
# 8     5297.0      142085.0       126.0  51874028.0
# 9     9227.0       33235.0        26.0  51815808.0

# %% [markdown]
# ## 3. Strategic Smpling

# %% [markdown]
# #### Sampling based on different Dates

# %%
print("Number of Samples will be :",len(Data.groupby(by='last_updated_date')))
for sample_name, samples in Data.groupby(by='last_updated_date'):
    print("Sample Name: ",sample_name)
    print("Sample Size: ",len(samples),"Rows")
    display(samples.reset_index(drop=True).head(10))
    print("\n")
# Out:
# Number of Samples will be : 2
# Sample Name:  2023-01-22
# Sample Size:  207 Rows
#   iso_code      continent        location last_updated_date  total_cases  \
# 0      USA  North America   United States        2023-01-22  102005805.0
# 1      IND           Asia           India        2023-01-22   44683239.0
# 2      FRA         Europe          France        2023-01-22   39516793.0
# 3      BRA  South America          Brazil        2023-01-22   36718053.0
# 4      JPN           Asia           Japan        2023-01-22   32067470.0
# 5      KOR           Asia     South Korea        2023-01-22   30008756.0
# 6      ITA         Europe           Italy        2023-01-22   25415630.0
# 7      GBR         Europe  United Kingdom        2023-01-22   24259240.0
# 8      TUR           Asia          Turkey        2023-01-22   17042722.0
# 9      ESP         Europe           Spain        2023-01-22   13722677.0
#
#    new_cases  total_deaths  new_deaths    population
# 0     2715.0     1104118.0        15.0  3.382899e+08
# 1       94.0      530735.0         2.0  1.417173e+09
# 2     4475.0      163821.0        44.0  6.781300e+07
# 3      552.0      696257.0         3.0  2.153135e+08
# 4    64450.0       65377.0       326.0  1.239517e+08
# 5     9227.0       33235.0        26.0  5.181581e+07
# 6    51888.0      186488.0       495.0  5.903747e+07
# 7    15847.0      216255.0      1377.0  6.750894e+07
# 8        0.0      101492.0         0.0  8.534125e+07
# 9    11426.0      118183.0       424.0  4.755863e+07
# Sample Name:  2023-01-23
# Sample Size:  7 Rows
#   iso_code      continent     location last_updated_date  total_cases  \
# 0      DEU         Europe      Germany        2023-01-23   37668384.0
# 1      RUS         Europe       Russia        2023-01-23   21585328.0
# 2      NLD         Europe  Netherlands        2023-01-23    8590602.0
# 3      AUT         Europe      Austria        2023-01-23    5755617.0
# 4      CHL  South America        Chile        2023-01-23    5103912.0
# 5      MYS           Asia     Malaysia        2023-01-23    5034830.0
# 6      DNK         Europe      Denmark        2023-01-23    3398106.0
#
#    new_cases  total_deaths  new_deaths   population
# 0     8866.0      164703.0       118.0   83369840.0
# 1     5691.0      386748.0        40.0  144713312.0
# 2      913.0       23079.0         0.0   17564020.0
# 3     1555.0       21626.0        13.0    8939617.0
# 4     2075.0       63667.0        27.0   19603736.0
# 5      309.0       36932.0         0.0   33938216.0
# 6      179.0        8072.0        19.0    5882259.0

# %% [markdown]
# #### Sampling based on different continets

# %%
print("Number of Samples will be :",len(Data.groupby(by='continent')))
for sample_name, samples in Data.groupby(by='continent'):
    print("Sample Name: ",sample_name)
    print("Sample Size: ",len(samples),"Rows")
    display(samples.reset_index(drop=True).head(10))
    print("\n")
# Out:
# Number of Samples will be : 6
# Sample Name:  Africa
# Sample Size:  54 Rows
#   iso_code continent      location last_updated_date  total_cases  new_cases  \
# 0      ZAF    Africa  South Africa        2023-01-22    4054160.0      364.0
# 1      MAR    Africa       Morocco        2023-01-22    1272164.0        2.0
# 2      TUN    Africa       Tunisia        2023-01-22    1150217.0     2488.0
# 3      EGY    Africa         Egypt        2023-01-22     515645.0        0.0
# 4      LBY    Africa         Libya        2023-01-22     507158.0        0.0
# 5      ETH    Africa      Ethiopia        2023-01-22     499306.0       11.0
# 6      KEN    Africa         Kenya        2023-01-22     342785.0        3.0
# 7      ZMB    Africa        Zambia        2023-01-22     338986.0      330.0
# 8      BWA    Africa      Botswana        2023-01-22     328581.0        0.0
# 9      MUS    Africa     Mauritius        2023-01-22     293386.0        0.0
#
#    total_deaths  new_deaths   population
# 0      102588.0        20.0   59893884.0
# 1       16296.0         0.0   37457976.0
# 2       29291.0         0.0   12356116.0
# 3       24805.0         0.0  110990096.0
# 4        6437.0         0.0    6812344.0
# 5        7572.0         0.0  123379928.0
# 6        5688.0         0.0   54027484.0
# 7        4039.0         0.0   20017670.0
# 8        2795.0         0.0    2630300.0
# 9        1042.0         0.0    1299478.0
# Sample Name:  Asia
# Sample Size:  49 Rows
#   iso_code continent     location last_updated_date  total_cases  new_cases  \
# 0      IND      Asia        India        2023-01-22   44683239.0       94.0
# 1      JPN      Asia        Japan        2023-01-22   32067470.0    64450.0
# 2      KOR      Asia  South Korea        2023-01-22   30008756.0     9227.0
# 3      TUR      Asia       Turkey        2023-01-22   17042722.0        0.0
# 4      VNM      Asia      Vietnam        2023-01-22   11526329.0       11.0
# 5      TWN      Asia       Taiwan        2023-01-22    9342958.0    19187.0
# 6      IRN      Asia         Iran        2023-01-22    7563385.0      112.0
# 7      IDN      Asia    Indonesia        2023-01-22    6728065.0      218.0
# 8      MYS      Asia     Malaysia        2023-01-23    5034830.0      309.0
# 9      ISR      Asia       Israel        2023-01-22    4780946.0      535.0
#
#    total_deaths  new_deaths    population
# 0      530735.0         2.0  1.417173e+09
# 1       65377.0       326.0  1.239517e+08
# 2       33235.0        26.0  5.181581e+07
# 3      101492.0         0.0  8.534125e+07
# 4       43186.0         0.0  9.818686e+07
# 5       16098.0        27.0  2.389340e+07
# 6      144735.0         1.0  8.855057e+07
# 7      160781.0         4.0  2.755013e+08
# 8       36932.0         0.0  3.393822e+07
# 9       12148.0         7.0  9.449000e+06
# Sample Name:  Europe
# Sample Size:  48 Rows
#   iso_code continent        location last_updated_date  total_cases  \
# 0      FRA    Europe          France        2023-01-22   39516793.0
# 1      DEU    Europe         Germany        2023-01-23   37668384.0
# 2      ITA    Europe           Italy        2023-01-22   25415630.0
# 3      GBR    Europe  United Kingdom        2023-01-22   24259240.0
# 4      RUS    Europe          Russia        2023-01-23   21585328.0
# 5      ESP    Europe           Spain        2023-01-22   13722677.0
# 6      NLD    Europe     Netherlands        2023-01-23    8590602.0
# 7      POL    Europe          Poland        2023-01-22    6375463.0
# 8      AUT    Europe         Austria        2023-01-23    5755617.0
# 9      UKR    Europe         Ukraine        2023-01-22    5675861.0
#
#    new_cases  total_deaths  new_deaths   population
# 0     4475.0      163821.0        44.0   67813000.0
# 1     8866.0      164703.0       118.0   83369840.0
# 2    51888.0      186488.0       495.0   59037472.0
# 3    15847.0      216255.0      1377.0   67508936.0
# 4     5691.0      386748.0        40.0  144713312.0
# 5    11426.0      118183.0       424.0   47558632.0
# 6      913.0       23079.0         0.0   17564020.0
# 7       73.0      118681.0         0.0   39857144.0
# 8     1555.0       21626.0        13.0    8939617.0
# 9       38.0      118924.0         1.0   39701744.0
# Sample Name:  North America
# Sample Size:  34 Rows
#   iso_code      continent            location last_updated_date  total_cases  \
# 0      USA  North America       United States        2023-01-22  102005805.0
# 1      MEX  North America              Mexico        2023-01-22    7342277.0
# 2      CAN  North America              Canada        2023-01-22    4551279.0
# 3      GTM  North America           Guatemala        2023-01-22    1222942.0
# 4      CRI  North America          Costa Rica        2023-01-22    1177514.0
# 5      CUB  North America                Cuba        2023-01-22    1112350.0
# 6      PAN  North America              Panama        2023-01-22    1028272.0
# 7      DOM  North America  Dominican Republic        2023-01-22     659761.0
# 8      HND  North America            Honduras        2023-01-22     470144.0
# 9      SLV  North America         El Salvador        2023-01-22     201785.0
#
#    new_cases  total_deaths  new_deaths   population
# 0     2715.0     1104118.0        15.0  338289856.0
# 1      797.0      331881.0        11.0  127504120.0
# 2      318.0       50248.0        11.0   38454328.0
# 3      243.0       20074.0         2.0   17843914.0
# 4     5712.0        9123.0        19.0    5180836.0
# 5        9.0        8530.0         0.0   11212198.0
# 6     1025.0        8589.0         0.0    4408582.0
# 7      155.0        4384.0         0.0   11228821.0
# 8      420.0       11099.0         0.0   10432858.0
# 9        0.0        4230.0         0.0    6336393.0
# Sample Name:  Oceania
# Sample Size:  17 Rows
#   iso_code continent              location last_updated_date  total_cases  \
# 0      AUS   Oceania             Australia        2023-01-22   11274262.0
# 1      NZL   Oceania           New Zealand        2023-01-22    2158663.0
# 2      NCL   Oceania         New Caledonia        2023-01-22      79921.0
# 3      PYF   Oceania      French Polynesia        2023-01-22      77957.0
# 4      FJI   Oceania                  Fiji        2023-01-22      68808.0
# 5      PNG   Oceania      Papua New Guinea        2023-01-22      46663.0
# 6      SLB   Oceania       Solomon Islands        2023-01-22      24575.0
# 7      FSM   Oceania  Micronesia (country)        2023-01-22      22676.0
# 8      TON   Oceania                 Tonga        2023-01-22      16590.0
# 9      WSM   Oceania                 Samoa        2023-01-22      16022.0
#
#    new_cases  total_deaths  new_deaths  population
# 0     8805.0       18092.0        69.0  26177410.0
# 1        0.0        2437.0         0.0   5185289.0
# 2        0.0         314.0         0.0    289959.0
# 3        0.0         649.0         0.0    306292.0
# 4        0.0         883.0         0.0    929769.0
# 5        0.0         669.0         0.0  10142625.0
# 6        0.0         153.0         0.0    724272.0
# 7      429.0          58.0         0.0    114178.0
# 8        0.0          13.0         0.0    106867.0
# 9        0.0          29.0         0.0    222390.0
# Sample Name:  South America
# Sample Size:  12 Rows
#   iso_code      continent   location last_updated_date  total_cases  \
# 0      BRA  South America     Brazil        2023-01-22   36718053.0
# 1      ARG  South America  Argentina        2023-01-22   10024095.0
# 2      COL  South America   Colombia        2023-01-22    6348356.0
# 3      CHL  South America      Chile        2023-01-23    5103912.0
# 4      PER  South America       Peru        2023-01-22    4478971.0
# 5      BOL  South America    Bolivia        2023-01-22    1183705.0
# 6      ECU  South America    Ecuador        2023-01-22    1047624.0
# 7      URY  South America    Uruguay        2023-01-22    1029564.0
# 8      PRY  South America   Paraguay        2023-01-22     805486.0
# 9      VEN  South America  Venezuela        2023-01-22     551283.0
#
#    new_cases  total_deaths  new_deaths   population
# 0      552.0      696257.0         3.0  215313504.0
# 1    19416.0      130338.0        89.0   45510324.0
# 2     5297.0      142085.0       126.0   51874028.0
# 3     2075.0       63667.0        27.0   19603736.0
# 4      279.0      218649.0        24.0   34049588.0
# 5      731.0       22342.0         0.0   12224114.0
# 6     7161.0       35940.0         0.0   18001002.0
# 7     3754.0        7597.0        11.0    3422796.0
# 8     5323.0       19778.0        32.0    6780745.0
# 9       79.0        5840.0         0.0   28301700.0

# %% [markdown]
# ## 4. Systematic Sampling

# %% [markdown]
# ### Sampling Bases on Intervals

# %% [markdown]
# For getting sample that have all values trend within it (means it have all range values of certain column rather than having only maximum or minimum). here the sample will be generated based on interval between Higest to lowest
# like only even index samples, odd index samples, etc.

# %% [markdown]
# #### Sampling based on total_cases column

# %%
samples=generateSystematicSamples(Data.copy(),'total_cases',number_of_samples=2,number_of_interval_for_selection=5)
for sample in samples:
    print("Sample Size: ",len(sample),"Rows")
    display(sample.head(10))
    print("\n")
# Out:
# Sample Size:  43 Rows
#   iso_code      continent       location last_updated_date  total_cases  \
# 0      USA  North America  United States        2023-01-22  102005805.0
# 1      JPN           Asia          Japan        2023-01-22   32067470.0
# 2      TUR           Asia         Turkey        2023-01-22   17042722.0
# 3      TWN           Asia         Taiwan        2023-01-22    9342958.0
# 4      POL         Europe         Poland        2023-01-22    6375463.0
# 5      GRC         Europe         Greece        2023-01-22    5548487.0
# 6      BEL         Europe        Belgium        2023-01-22    4688927.0
# 7      PHL           Asia    Philippines        2023-01-22    4071963.0
# 8      SWE         Europe         Sweden        2023-01-22    2690473.0
# 9      HUN         Europe        Hungary        2023-01-22    2191200.0
#
#    new_cases  total_deaths  new_deaths   population
# 0     2715.0     1104118.0        15.0  338289856.0
# 1    64450.0       65377.0       326.0  123951696.0
# 2        0.0      101492.0         0.0   85341248.0
# 3    19187.0       16098.0        27.0   23893396.0
# 4       73.0      118681.0         0.0   39857144.0
# 5        0.0       34779.0         0.0   10384972.0
# 6     2780.0       33525.0        47.0   11655923.0
# 7      423.0       65694.0        14.0  115559008.0
# 8     2633.0       23020.0       375.0   10549349.0
# 9      866.0       48629.0        51.0    9967304.0
# Sample Size:  43 Rows
#   iso_code      continent      location last_updated_date  total_cases  \
# 0      IND           Asia         India        2023-01-22   44683239.0
# 1      KOR           Asia   South Korea        2023-01-22   30008756.0
# 2      ESP         Europe         Spain        2023-01-22   13722677.0
# 3      NLD         Europe   Netherlands        2023-01-23    8590602.0
# 4      COL  South America      Colombia        2023-01-22    6348356.0
# 5      CHL  South America         Chile        2023-01-23    5103912.0
# 6      CZE         Europe       Czechia        2023-01-22    4586781.0
# 7      ZAF         Africa  South Africa        2023-01-22    4054160.0
# 8      SVK         Europe      Slovakia        2023-01-22    2659881.0
# 9      NZL        Oceania   New Zealand        2023-01-22    2158663.0
#
#    new_cases  total_deaths  new_deaths    population
# 0       94.0      530735.0         2.0  1.417173e+09
# 1     9227.0       33235.0        26.0  5.181581e+07
# 2    11426.0      118183.0       424.0  4.755863e+07
# 3      913.0       23079.0         0.0  1.756402e+07
# 4     5297.0      142085.0       126.0  5.187403e+07
# 5     2075.0       63667.0        27.0  1.960374e+07
# 6       50.0       42280.0         0.0  1.049399e+07
# 7      364.0      102588.0        20.0  5.989388e+07
# 8       28.0       20906.0         5.0  5.643455e+06
# 9        0.0        2437.0         0.0  5.185289e+06

# %% [markdown]
# #### Sampling based on continent column

# %%
samples=generateSystematicSamples(Data.copy(),'continent',number_of_samples=2,number_of_interval_for_selection=5)
for sample in samples:
    print("Sample Size: ",len(sample),"Rows")
    display(sample.head(10))
    print("\n")
# Out:
# Sample Size:  43 Rows
#   iso_code      continent             location last_updated_date  total_cases  \
# 0      VEN  South America            Venezuela        2023-01-22     551283.0
# 1      BRA  South America               Brazil        2023-01-22   36718053.0
# 2      URY  South America              Uruguay        2023-01-22    1029564.0
# 3      MHL        Oceania     Marshall Islands        2023-01-22      15554.0
# 4      VUT        Oceania              Vanuatu        2023-01-22      12014.0
# 5      PNG        Oceania     Papua New Guinea        2023-01-22      46663.0
# 6      USA  North America        United States        2023-01-22  102005805.0
# 7      ATG  North America  Antigua and Barbuda        2023-01-22       9106.0
# 8      CAN  North America               Canada        2023-01-22    4551279.0
# 9      GRD  North America              Grenada        2023-01-22      19680.0
#
#    new_cases  total_deaths  new_deaths   population
# 0       79.0        5840.0         0.0   28301700.0
# 1      552.0      696257.0         3.0  215313504.0
# 2     3754.0        7597.0        11.0    3422796.0
# 3        0.0          17.0         0.0      41593.0
# 4        0.0          14.0         0.0     326744.0
# 5        0.0         669.0         0.0   10142625.0
# 6     2715.0     1104118.0        15.0  338289856.0
# 7        0.0         146.0         0.0      93772.0
# 8      318.0       50248.0        11.0   38454328.0
# 9        0.0         238.0         0.0     125459.0
# Sample Size:  43 Rows
#   iso_code      continent                   location last_updated_date  \
# 0      ECU  South America                    Ecuador        2023-01-22
# 1      CHL  South America                      Chile        2023-01-23
# 2      COL  South America                   Colombia        2023-01-22
# 3      FSM        Oceania       Micronesia (country)        2023-01-22
# 4      WLF        Oceania          Wallis and Futuna        2023-01-22
# 5      NCL        Oceania              New Caledonia        2023-01-22
# 6      TCA  North America   Turks and Caicos Islands        2023-01-22
# 7      SPM  North America  Saint Pierre and Miquelon        2023-01-22
# 8      MEX  North America                     Mexico        2023-01-22
# 9      CUW  North America                    Curacao        2023-01-22
#
#    total_cases  new_cases  total_deaths  new_deaths   population
# 0    1047624.0     7161.0       35940.0         0.0   18001002.0
# 1    5103912.0     2075.0       63667.0        27.0   19603736.0
# 2    6348356.0     5297.0      142085.0       126.0   51874028.0
# 3      22676.0      429.0          58.0         0.0     114178.0
# 4       3427.0        0.0           7.0         0.0      11596.0
# 5      79921.0        0.0         314.0         0.0     289959.0
# 6       6522.0        0.0          38.0         0.0      45726.0
# 7       3411.0        0.0           2.0         0.0       5885.0
# 8    7342277.0      797.0      331881.0        11.0  127504120.0
# 9      45986.0        0.0         301.0         0.0     191173.0
