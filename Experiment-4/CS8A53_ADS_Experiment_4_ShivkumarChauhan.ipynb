# %% [markdown]
# ## Name: Shivkumar G. Chauhan
# ### Roll No.: CS8A53
# ### Batch A-3
# ---
# # Experiment - 4 : Apply data preprocessing techniques.

# %% [markdown]
# ## imports

# %%
import pandas
import numpy
import warnings
from sklearn import preprocessing

# %% [markdown]
# ## Configurations

# %%
StandardScaler=preprocessing.StandardScaler(
    with_mean=False,
    with_std=True
)
Normalizer=preprocessing.Normalizer(
    norm='max'
)

# %% [markdown]
# hiding warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# reading dataset

# %%
Raw_Data=pandas.read_csv("../Data/Raw_Data/owid-covid-data.csv",date_parser='date')

# %% [markdown]
# Sorting the Dataframe using total_cases column

# %% [markdown]
# selecting specific columns

# %%
Raw_Data=Raw_Data.sort_values(
    by="total_cases",
    ascending=True
).reset_index(drop=True)

# %%
Selected_Columns=['iso_code','date', 'continent', 'location', 'total_cases','new_cases', 'total_deaths', 'new_deaths','population','life_expectancy']

# %% [markdown]
# Location Specific Data

# %% [markdown]
# Last Updated Aggreated Data

# %%
location="India"

# %%
Aggregated_Data_by_Location=Raw_Data.groupby(
    by='location'
).max('total_cases')

# %%
Location_Specific_Data=Raw_Data[
    Raw_Data['location']==location
]

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Raw Data

# %% [markdown]
# printing Checking of Raw dataset

# %%
Raw_Data
# Out:
#        iso_code      continent             location        date  total_cases  \
# 0           ATG  North America  Antigua and Barbuda  2020-03-15          1.0
# 1           WLF        Oceania    Wallis and Futuna  2020-11-14          1.0
# 2           WLF        Oceania    Wallis and Futuna  2020-11-15          1.0
# 3           WLF        Oceania    Wallis and Futuna  2020-11-16          1.0
# 4           SMR         Europe           San Marino  2020-02-28          1.0
# ...         ...            ...                  ...         ...          ...
# 297147      ZWE         Africa             Zimbabwe  2020-03-16          NaN
# 297148      ZWE         Africa             Zimbabwe  2020-03-17          NaN
# 297149      ZWE         Africa             Zimbabwe  2020-03-18          NaN
# 297150      ZWE         Africa             Zimbabwe  2020-03-19          NaN
# 297151      ZWE         Africa             Zimbabwe  2020-03-20          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0             1.0               0.143           NaN         0.0
# 1             0.0               0.000           NaN         0.0
# 2             0.0               0.000           NaN         0.0
# 3             0.0               0.000           NaN         0.0
# 4             1.0               0.143           NaN         0.0
# ...           ...                 ...           ...         ...
# 297147        0.0               0.000           5.0         0.0
# 297148        0.0               0.000           5.0         0.0
# 297149        0.0               0.000           5.0         0.0
# 297150        0.0               0.000           5.0         0.0
# 297151        0.0               0.000           5.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 0                       0.0  ...           NaN                     NaN
# 1                       0.0  ...           NaN                     NaN
# 2                       0.0  ...           NaN                     NaN
# 3                       0.0  ...           NaN                     NaN
# 4                       0.0  ...           NaN                     NaN
# ...                     ...  ...           ...                     ...
# 297147                  0.0  ...          30.7                  36.791
# 297148                  0.0  ...          30.7                  36.791
# 297149                  0.0  ...          30.7                  36.791
# 297150                  0.0  ...          30.7                  36.791
# 297151                  0.0  ...          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              3.8            77.02                    0.778
# 1                              NaN            79.94                      NaN
# 2                              NaN            79.94                      NaN
# 3                              NaN            79.94                      NaN
# 4                              3.8            84.97                      NaN
# ...                            ...              ...                      ...
# 297147                         1.7            61.49                    0.571
# 297148                         1.7            61.49                    0.571
# 297149                         1.7            61.49                    0.571
# 297150                         1.7            61.49                    0.571
# 297151                         1.7            61.49                    0.571
#
#         population  excess_mortality_cumulative_absolute  \
# 0          93772.0                                   NaN
# 1          11596.0                                   NaN
# 2          11596.0                                   NaN
# 3          11596.0                                   NaN
# 4          33690.0                                   NaN
# ...            ...                                   ...
# 297147  16320539.0                                   NaN
# 297148  16320539.0                                   NaN
# 297149  16320539.0                                   NaN
# 297150  16320539.0                                   NaN
# 297151  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 297147                          NaN               NaN
# 297148                          NaN               NaN
# 297149                          NaN               NaN
# 297150                          NaN               NaN
# 297151                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 297147                                      NaN
# 297148                                      NaN
# 297149                                      NaN
# 297150                                      NaN
# 297151                                      NaN
#
# [297152 rows x 67 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Raw_Data.describe(include="all")
# Out:
#        iso_code continent   location        date   total_cases     new_cases  \
# count    297152    283021     297152      297152  2.614010e+05  2.886750e+05
# unique      255         6        255        1181           NaN           NaN
# top         ARG    Africa  Argentina  2022-04-20           NaN           NaN
# freq       1180     66919       1180         255           NaN           NaN
# mean        NaN       NaN        NaN         NaN  5.367080e+06  1.117552e+04
# std         NaN       NaN        NaN         NaN  3.374066e+07  1.052843e+05
# min         NaN       NaN        NaN         NaN  1.000000e+00  0.000000e+00
# 25%         NaN       NaN        NaN         NaN  5.999000e+03  0.000000e+00
# 50%         NaN       NaN        NaN         NaN  5.800800e+04  2.100000e+01
# 75%         NaN       NaN        NaN         NaN  5.985810e+05  5.800000e+02
# max         NaN       NaN        NaN         NaN  7.610711e+08  7.946912e+06
#
#         new_cases_smoothed  total_deaths     new_deaths  new_deaths_smoothed  \
# count         2.874110e+05  2.409870e+05  288741.000000        287511.000000
# unique                 NaN           NaN            NaN                  NaN
# top                    NaN           NaN            NaN                  NaN
# freq                   NaN           NaN            NaN                  NaN
# mean          1.122060e+04  7.798592e+04      99.555030            99.947194
# std           1.025490e+05  4.045377e+05     612.409212           602.917596
# min           0.000000e+00  1.000000e+00       0.000000             0.000000
# 25%           1.286000e+00  1.160000e+02       0.000000             0.000000
# 50%           4.142900e+01  1.163000e+03       0.000000             0.286000
# 75%           6.674290e+02  1.015950e+04       6.000000             7.143000
# max           6.405128e+06  6.879664e+06   20005.000000         14581.286000
#
#         ...   male_smokers  handwashing_facilities  \
# count   ...  170354.000000           112729.000000
# unique  ...            NaN                     NaN
# top     ...            NaN                     NaN
# freq    ...            NaN                     NaN
# mean    ...      32.911114               50.794994
# std     ...      13.572942               31.957226
# min     ...       7.700000                1.188000
# 25%     ...      22.600000               20.859000
# 50%     ...      33.100000               49.839000
# 75%     ...      41.300000               83.241000
# max     ...      78.100000              100.000000
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                203231.000000    273235.000000            223159.000000
# unique                         NaN              NaN                      NaN
# top                            NaN              NaN                      NaN
# freq                           NaN              NaN                      NaN
# mean                      3.098023        73.721018                 0.722548
# std                       2.548891         7.397070                 0.148996
# min                       0.100000        53.280000                 0.394000
# 25%                       1.300000        69.590000                 0.602000
# 50%                       2.500000        75.050000                 0.740000
# 75%                       4.200000        79.460000                 0.829000
# max                      13.800000        86.750000                 0.957000
#
#           population  excess_mortality_cumulative_absolute  \
# count   2.971520e+05                          1.020500e+04
# unique           NaN                                   NaN
# top              NaN                                   NaN
# freq             NaN                                   NaN
# mean    1.283638e+08                          4.683279e+04
# std     6.605372e+08                          1.371560e+05
# min     4.700000e+01                         -3.772610e+04
# 25%     4.490020e+05                          1.930000e+01
# 50%     5.882259e+06                          4.342600e+03
# 75%     2.830170e+07                          3.104800e+04
# max     7.975105e+09                          1.282260e+06
#
#         excess_mortality_cumulative  excess_mortality  \
# count                  10205.000000      10205.000000
# unique                          NaN               NaN
# top                             NaN               NaN
# freq                            NaN               NaN
# mean                       9.488196         13.073035
# std                       13.099374         26.692084
# min                      -44.230000        -95.920000
# 25%                        0.370000         -0.990000
# 50%                        7.690000          6.800000
# 75%                       15.460000         18.620000
# max                       76.550000        376.770000
#
#         excess_mortality_cumulative_per_million
# count                              10205.000000
# unique                                      NaN
# top                                         NaN
# freq                                        NaN
# mean                                1437.715461
# std                                 1822.875623
# min                                -1984.281600
# 25%                                   12.528376
# 50%                                  863.340940
# 75%                                 2344.063000
# max                                10329.523000
#
# [11 rows x 67 columns]

# %% [markdown]
# printing the dataset information like column values counts, column value data type

# %%
Raw_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297152 entries, 0 to 297151
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    297152 non-null  object
#  1   continent                                   283021 non-null  object
#  2   location                                    297152 non-null  object
#  3   date                                        297152 non-null  object
#  4   total_cases                                 261401 non-null  float64
#  5   new_cases                                   288675 non-null  float64
#  6   new_cases_smoothed                          287411 non-null  float64
#  7   total_deaths                                240987 non-null  float64
#  8   new_deaths                                  288741 non-null  float64
#  9   new_deaths_smoothed                         287511 non-null  float64
#  10  total_cases_per_million                     261401 non-null  float64
#  11  new_cases_per_million                       288675 non-null  float64
#  12  new_cases_smoothed_per_million              287411 non-null  float64
#  13  total_deaths_per_million                    240987 non-null  float64
#  14  new_deaths_per_million                      288741 non-null  float64
#  15  new_deaths_smoothed_per_million             287511 non-null  float64
#  16  reproduction_rate                           184817 non-null  float64
#  17  icu_patients                                34239 non-null   float64
#  18  icu_patients_per_million                    34239 non-null   float64
#  19  hosp_patients                               34744 non-null   float64
#  20  hosp_patients_per_million                   34744 non-null   float64
#  21  weekly_icu_admissions                       8961 non-null    float64
#  22  weekly_icu_admissions_per_million           8961 non-null    float64
#  23  weekly_hosp_admissions                      21049 non-null   float64
#  24  weekly_hosp_admissions_per_million          21049 non-null   float64
#  25  total_tests                                 79387 non-null   float64
#  26  new_tests                                   75403 non-null   float64
#  27  total_tests_per_thousand                    79387 non-null   float64
#  28  new_tests_per_thousand                      75403 non-null   float64
#  29  new_tests_smoothed                          103965 non-null  float64
#  30  new_tests_smoothed_per_thousand             103965 non-null  float64
#  31  positive_rate                               95927 non-null   float64
#  32  tests_per_case                              94348 non-null   float64
#  33  tests_units                                 106788 non-null  object
#  34  total_vaccinations                          73463 non-null   float64
#  35  people_vaccinated                           70359 non-null   float64
#  36  people_fully_vaccinated                     68041 non-null   float64
#  37  total_boosters                              42261 non-null   float64
#  38  new_vaccinations                            60710 non-null   float64
#  39  new_vaccinations_smoothed                   160807 non-null  float64
#  40  total_vaccinations_per_hundred              73463 non-null   float64
#  41  people_vaccinated_per_hundred               70359 non-null   float64
#  42  people_fully_vaccinated_per_hundred         68041 non-null   float64
#  43  total_boosters_per_hundred                  42261 non-null   float64
#  44  new_vaccinations_smoothed_per_million       160807 non-null  float64
#  45  new_people_vaccinated_smoothed              160918 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  160918 non-null  float64
#  47  stringency_index                            193194 non-null  float64
#  48  population_density                          252112 non-null  float64
#  49  median_age                                  234493 non-null  float64
#  50  aged_65_older                               226284 non-null  float64
#  51  aged_70_older                               232140 non-null  float64
#  52  gdp_per_capita                              229803 non-null  float64
#  53  extreme_poverty                             148020 non-null  float64
#  54  cardiovasc_death_rate                       230223 non-null  float64
#  55  diabetes_prevalence                         241946 non-null  float64
#  56  female_smokers                              172707 non-null  float64
#  57  male_smokers                                170354 non-null  float64
#  58  handwashing_facilities                      112729 non-null  float64
#  59  hospital_beds_per_thousand                  203231 non-null  float64
#  60  life_expectancy                             273235 non-null  float64
#  61  human_development_index                     223159 non-null  float64
#  62  population                                  297152 non-null  float64
#  63  excess_mortality_cumulative_absolute        10205 non-null   float64
#  64  excess_mortality_cumulative                 10205 non-null   float64
#  65  excess_mortality                            10205 non-null   float64
#  66  excess_mortality_cumulative_per_million     10205 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 151.9+ MB

# %% [markdown]
# ## Location Specific Data

# %% [markdown]
# Printing Location Specific Data

# %%
Location_Specific_Data.head()
# Out:
#      iso_code continent location        date  total_cases  new_cases  \
# 1144      IND      Asia    India  2020-01-30          1.0        1.0
# 1710      IND      Asia    India  2020-02-02          2.0        NaN
# 2307      IND      Asia    India  2020-02-03          3.0        1.0
# 4604      IND      Asia    India  2020-01-31          5.0        4.0
# 4605      IND      Asia    India  2020-02-01          5.0        0.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 1144               0.143           NaN         0.0                  0.0  ...
# 1710                 NaN           NaN         0.0                  0.0  ...
# 2307               0.857           NaN         0.0                  0.0  ...
# 4604               0.714           NaN         0.0                  0.0  ...
# 4605               0.714           NaN         0.0                  0.0  ...
#
#       male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 1144          20.6                   59.55                        0.53
# 1710          20.6                   59.55                        0.53
# 2307          20.6                   59.55                        0.53
# 4604          20.6                   59.55                        0.53
# 4605          20.6                   59.55                        0.53
#
#       life_expectancy  human_development_index    population  \
# 1144            69.66                    0.645  1.417173e+09
# 1710            69.66                    0.645  1.417173e+09
# 2307            69.66                    0.645  1.417173e+09
# 4604            69.66                    0.645  1.417173e+09
# 4605            69.66                    0.645  1.417173e+09
#
#       excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 1144                                   NaN                          NaN
# 1710                                   NaN                          NaN
# 2307                                   NaN                          NaN
# 4604                                   NaN                          NaN
# 4605                                   NaN                          NaN
#
#       excess_mortality  excess_mortality_cumulative_per_million
# 1144               NaN                                      NaN
# 1710               NaN                                      NaN
# 2307               NaN                                      NaN
# 4604               NaN                                      NaN
# 4605               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Location_Specific_Data.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  1.147000e+03    1171.000000         1166.000000    1104.000000
# mean   2.582627e+07   38170.570453        38331.506116  335841.667572
# std    1.755011e+07   71005.505886        70558.344671  202971.144119
# min    1.000000e+00       0.000000            0.000000       1.000000
# 25%    8.659964e+06    1769.500000         1896.928750  143271.000000
# 50%    3.251237e+07   13052.000000        13295.643000  443712.500000
# 75%    4.318767e+07   41258.500000        40619.714500  524843.750000
# max    4.469698e+07  414188.000000       391279.571000  530808.000000
#
#         new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  1174.000000          1169.000000              1147.000000
# mean    452.136286           454.061965             18223.793786
# std     806.654970           775.305346             12383.887300
# min       0.000000             0.000000                 0.001000
# 25%      17.000000            21.714000              6110.730500
# 50%     161.500000           209.143000             22941.704000
# 75%     505.500000           518.286000             30474.516500
# max    6148.000000          4190.000000             31539.537000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count            1171.000000                     1166.000000
# mean               26.934286                       27.047864
# std                50.103628                       49.788082
# min                 0.000000                        0.000000
# 25%                 1.249000                        1.338750
# 50%                 9.210000                        9.381500
# 75%                29.113000                       28.662500
# max               292.264000                      276.099000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count               1104.000000  ...  1.179000e+03            1.179000e+03
# mean                 236.979976  ...  2.060000e+01            5.955000e+01
# std                  143.222546  ...  7.108443e-15            1.421689e-14
# min                    0.001000  ...  2.060000e+01            5.955000e+01
# 25%                  101.096750  ...  2.060000e+01            5.955000e+01
# 50%                  313.097000  ...  2.060000e+01            5.955000e+01
# 75%                  370.345500  ...  2.060000e+01            5.955000e+01
# max                  374.554000  ...  2.060000e+01            5.955000e+01
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                1.179000e+03     1.179000e+03             1.179000e+03
# mean                 5.300000e-01     6.966000e+01             6.450000e-01
# std                  2.221388e-16     2.843377e-14             1.110694e-16
# min                  5.300000e-01     6.966000e+01             6.450000e-01
# 25%                  5.300000e-01     6.966000e+01             6.450000e-01
# 50%                  5.300000e-01     6.966000e+01             6.450000e-01
# 75%                  5.300000e-01     6.966000e+01             6.450000e-01
# max                  5.300000e-01     6.966000e+01             6.450000e-01
#
#          population  excess_mortality_cumulative_absolute  \
# count  1.179000e+03                                   0.0
# mean   1.417173e+09                                   NaN
# std    0.000000e+00                                   NaN
# min    1.417173e+09                                   NaN
# 25%    1.417173e+09                                   NaN
# 50%    1.417173e+09                                   NaN
# 75%    1.417173e+09                                   NaN
# max    1.417173e+09                                   NaN
#
#        excess_mortality_cumulative  excess_mortality  \
# count                          0.0               0.0
# mean                           NaN               NaN
# std                            NaN               NaN
# min                            NaN               NaN
# 25%                            NaN               NaN
# 50%                            NaN               NaN
# 75%                            NaN               NaN
# max                            NaN               NaN
#
#        excess_mortality_cumulative_per_million
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
# [8 rows x 62 columns]

# %% [markdown]
# ## Last Updated Aggreated Data

# %% [markdown]
# Printing Last Updated Aggreated Data

# %%
Aggregated_Data_by_Location
# Out:
#                 total_cases  new_cases  new_cases_smoothed  total_deaths  \
# location
# Afghanistan        209848.0     3243.0            2095.571        7881.0
# Africa           13063768.0    72463.0           46909.143      258788.0
# Albania            333726.0     2832.0            2210.286        3601.0
# Algeria            271542.0     2521.0            2177.571        6881.0
# American Samoa       8321.0      955.0             307.714          34.0
# ...                     ...        ...                 ...           ...
# Western Sahara          NaN        NaN                 NaN           NaN
# World           761071062.0  7946912.0         6405127.857     6879664.0
# Yemen               11945.0      287.0             109.429        2159.0
# Zambia             343250.0     5555.0            3870.857        4057.0
# Zimbabwe           264391.0     6181.0            4579.714        5672.0
#
#                 new_deaths  new_deaths_smoothed  total_cases_per_million  \
# location
# Afghanistan          159.0               97.571                 5102.219
# Africa              1525.0             1020.714                 9156.398
# Albania               21.0               20.429               117413.323
# Algeria               49.0               38.286                 6047.271
# American Samoa         5.0                1.429               187854.160
# ...                    ...                  ...                      ...
# Western Sahara         NaN                  NaN                      NaN
# World              20005.0            14581.286                95430.851
# Yemen                 60.0               16.429                  354.487
# Zambia                72.0               61.429                17147.350
# Zimbabwe             107.0               78.714                16199.894
#
#                 new_cases_per_million  new_cases_smoothed_per_million  \
# location
# Afghanistan                    78.850                          50.951
# Africa                         50.789                          32.879
# Albania                       996.370                         777.635
# Algeria                        56.143                          48.495
# American Samoa              21559.995                        6946.930
# ...                               ...                             ...
# Western Sahara                    NaN                             NaN
# World                         996.465                         803.140
# Yemen                           8.517                           3.247
# Zambia                        277.505                         193.372
# Zimbabwe                      378.725                         280.610
#
#                 total_deaths_per_million  ...  male_smokers  \
# location                                  ...
# Afghanistan                      191.618  ...           NaN
# Africa                           181.385  ...           NaN
# Albania                         1266.924  ...        51.200
# Algeria                          153.241  ...        30.400
# American Samoa                   767.581  ...           NaN
# ...                                  ...  ...           ...
# Western Sahara                       NaN  ...           NaN
# World                            862.642  ...        34.635
# Yemen                             64.072  ...        29.200
# Zambia                           202.671  ...        24.700
# Zimbabwe                         347.538  ...        30.700
#
#                 handwashing_facilities  hospital_beds_per_thousand  \
# location
# Afghanistan                     37.746                       0.500
# Africa                             NaN                         NaN
# Albania                            NaN                       2.890
# Algeria                         83.741                       1.900
# American Samoa                     NaN                         NaN
# ...                                ...                         ...
# Western Sahara                     NaN                         NaN
# World                           60.130                       2.705
# Yemen                           49.542                       0.700
# Zambia                          13.938                       2.000
# Zimbabwe                        36.791                       1.700
#
#                 life_expectancy  human_development_index    population  \
# location
# Afghanistan               64.83                    0.511  4.112877e+07
# Africa                      NaN                      NaN  1.426737e+09
# Albania                   78.57                    0.795  2.842318e+06
# Algeria                   76.88                    0.748  4.490323e+07
# American Samoa            73.74                      NaN  4.429500e+04
# ...                         ...                      ...           ...
# Western Sahara            70.26                      NaN  5.760050e+05
# World                     72.58                    0.737  7.975105e+09
# Yemen                     66.12                    0.470  3.369661e+07
# Zambia                    63.89                    0.584  2.001767e+07
# Zimbabwe                  61.49                    0.571  1.632054e+07
#
#                 excess_mortality_cumulative_absolute  \
# location
# Afghanistan                                      NaN
# Africa                                           NaN
# Albania                                    16603.998
# Algeria                                    49888.703
# American Samoa                                   NaN
# ...                                              ...
# Western Sahara                                   NaN
# World                                            NaN
# Yemen                                            NaN
# Zambia                                           NaN
# Zimbabwe                                         NaN
#
#                 excess_mortality_cumulative  excess_mortality  \
# location
# Afghanistan                             NaN               NaN
# Africa                                  NaN               NaN
# Albania                               34.73            120.15
# Algeria                               26.86            110.72
# American Samoa                          NaN               NaN
# ...                                     ...               ...
# Western Sahara                          NaN               NaN
# World                                   NaN               NaN
# Yemen                                   NaN               NaN
# Zambia                                  NaN               NaN
# Zimbabwe                                NaN               NaN
#
#                 excess_mortality_cumulative_per_million
# location
# Afghanistan                                         NaN
# Africa                                              NaN
# Albania                                       5841.7100
# Algeria                                       1148.1425
# American Samoa                                      NaN
# ...                                                 ...
# Western Sahara                                      NaN
# World                                               NaN
# Yemen                                               NaN
# Zambia                                              NaN
# Zimbabwe                                            NaN
#
# [255 rows x 62 columns]

# %% [markdown]
# printing different statistics of dataset like mean, quantiles, min, max etc.

# %%
Aggregated_Data_by_Location.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.440000e+02  2.460000e+02        2.460000e+02  2.370000e+02
# mean   1.322130e+07  1.921253e+05        1.509240e+05  1.212382e+05
# std    6.458998e+07  9.601383e+05        7.954972e+05  5.677230e+05
# min    4.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.783275e+04  1.074500e+03        4.021072e+02  2.590000e+02
# 50%    2.424370e+05  3.832000e+03        2.193928e+03  2.795000e+03
# 75%    1.715720e+06  2.464675e+04        1.508789e+04  1.988000e+04
# max    7.610711e+08  7.946912e+06        6.405128e+06  6.879664e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count    246.000000           246.000000               244.000000
# mean     710.418699           425.224752            199236.108311
# std     2321.571526          1449.128809            194426.138220
# min        0.000000             0.000000               354.487000
# 25%       10.000000             3.143000             24063.459500
# 50%       49.000000            20.857500            135324.783000
# 75%      245.250000           110.035500            331699.877500
# max    20005.000000         14581.286000            729533.363000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count             246.000000                      246.000000
# mean             9917.960016                     3165.973585
# std             25744.922960                     5328.762880
# min                 0.000000                        0.000000
# 25%               330.879750                      214.061250
# 50%              2312.613000                     1474.404000
# 75%              7085.378250                     4044.664750
# max            228872.025000                    37241.781000
#
#        total_deaths_per_million  ...  male_smokers  handwashing_facilities  \
# count                237.000000  ...    145.000000               96.000000
# mean                1287.243021  ...     32.909897               50.788844
# std                 1279.438282  ...     13.621757               32.124848
# min                    1.164000  ...      7.700000                1.188000
# 25%                  191.618000  ...     22.600000               20.482000
# 50%                  945.525000  ...     33.100000               49.690500
# 75%                 2036.568000  ...     41.300000               82.686750
# max                 6450.827000  ...     78.100000              100.000000
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# count                  173.000000       234.000000               190.000000
# mean                     3.097012        73.720598                 0.722500
# std                      2.555777         7.406984                 0.149398
# min                      0.100000        53.280000                 0.394000
# 25%                      1.300000        69.607500                 0.603000
# 50%                      2.500000        75.050000                 0.740000
# 75%                      4.200000        79.440000                 0.828750
# max                     13.800000        86.750000                 0.957000
#
#          population  excess_mortality_cumulative_absolute  \
# count  2.550000e+02                          1.230000e+02
# mean   1.270264e+08                          7.397888e+04
# std    6.581601e+08                          1.926902e+05
# min    4.700000e+01                         -1.860000e+01
# 25%    4.864000e+05                          1.298600e+03
# 50%    5.643455e+06                          1.601400e+04
# 75%    2.823112e+07                          4.838794e+04
# max    7.975105e+09                          1.282260e+06
#
#        excess_mortality_cumulative  excess_mortality  \
# count                   123.000000        123.000000
# mean                     19.618780        102.652683
# std                      14.023782         61.604822
# min                      -4.690000         18.750000
# 25%                       9.815000         63.310000
# 50%                      17.520000         86.620000
# 75%                      25.885000        129.840000
# max                      76.550000        376.770000
#
#        excess_mortality_cumulative_per_million
# count                               123.000000
# mean                               2793.084122
# std                                2138.325905
# min                                -228.832950
# 25%                                1191.667650
# 50%                                2340.893600
# 75%                                3894.599350
# max                               10329.523000
#
# [8 rows x 62 columns]

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Selection of Data on which Preprocessing should be performed and also creating backup of original Data

# %%
Main_Data=Raw_Data.copy()

# %%
Main_Data
# Out:
#        iso_code      continent             location        date  total_cases  \
# 0           ATG  North America  Antigua and Barbuda  2020-03-15          1.0
# 1           WLF        Oceania    Wallis and Futuna  2020-11-14          1.0
# 2           WLF        Oceania    Wallis and Futuna  2020-11-15          1.0
# 3           WLF        Oceania    Wallis and Futuna  2020-11-16          1.0
# 4           SMR         Europe           San Marino  2020-02-28          1.0
# ...         ...            ...                  ...         ...          ...
# 297147      ZWE         Africa             Zimbabwe  2020-03-16          NaN
# 297148      ZWE         Africa             Zimbabwe  2020-03-17          NaN
# 297149      ZWE         Africa             Zimbabwe  2020-03-18          NaN
# 297150      ZWE         Africa             Zimbabwe  2020-03-19          NaN
# 297151      ZWE         Africa             Zimbabwe  2020-03-20          NaN
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0             1.0               0.143           NaN         0.0
# 1             0.0               0.000           NaN         0.0
# 2             0.0               0.000           NaN         0.0
# 3             0.0               0.000           NaN         0.0
# 4             1.0               0.143           NaN         0.0
# ...           ...                 ...           ...         ...
# 297147        0.0               0.000           5.0         0.0
# 297148        0.0               0.000           5.0         0.0
# 297149        0.0               0.000           5.0         0.0
# 297150        0.0               0.000           5.0         0.0
# 297151        0.0               0.000           5.0         0.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# 0                       0.0  ...           NaN                     NaN
# 1                       0.0  ...           NaN                     NaN
# 2                       0.0  ...           NaN                     NaN
# 3                       0.0  ...           NaN                     NaN
# 4                       0.0  ...           NaN                     NaN
# ...                     ...  ...           ...                     ...
# 297147                  0.0  ...          30.7                  36.791
# 297148                  0.0  ...          30.7                  36.791
# 297149                  0.0  ...          30.7                  36.791
# 297150                  0.0  ...          30.7                  36.791
# 297151                  0.0  ...          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              3.8            77.02                    0.778
# 1                              NaN            79.94                      NaN
# 2                              NaN            79.94                      NaN
# 3                              NaN            79.94                      NaN
# 4                              3.8            84.97                      NaN
# ...                            ...              ...                      ...
# 297147                         1.7            61.49                    0.571
# 297148                         1.7            61.49                    0.571
# 297149                         1.7            61.49                    0.571
# 297150                         1.7            61.49                    0.571
# 297151                         1.7            61.49                    0.571
#
#         population  excess_mortality_cumulative_absolute  \
# 0          93772.0                                   NaN
# 1          11596.0                                   NaN
# 2          11596.0                                   NaN
# 3          11596.0                                   NaN
# 4          33690.0                                   NaN
# ...            ...                                   ...
# 297147  16320539.0                                   NaN
# 297148  16320539.0                                   NaN
# 297149  16320539.0                                   NaN
# 297150  16320539.0                                   NaN
# 297151  16320539.0                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               NaN               NaN
# 1                               NaN               NaN
# 2                               NaN               NaN
# 3                               NaN               NaN
# 4                               NaN               NaN
# ...                             ...               ...
# 297147                          NaN               NaN
# 297148                          NaN               NaN
# 297149                          NaN               NaN
# 297150                          NaN               NaN
# 297151                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 297147                                      NaN
# 297148                                      NaN
# 297149                                      NaN
# 297150                                      NaN
# 297151                                      NaN
#
# [297152 rows x 67 columns]

# %% [markdown]
# ## 1. Data Reduction

# %% [markdown]
# ### Dimensionality Reduction

# %% [markdown]
# #### Feature selection method with forward Selection type

# %%
", ".join(Selected_Columns)
# Out:
# 'iso_code, date, continent, location, total_cases, new_cases, total_deaths, new_deaths, population, life_expectancy'

# %%
Main_Data=Main_Data[Selected_Columns]

# %%
Main_Data
# Out:
#        iso_code        date      continent             location  total_cases  \
# 0           ATG  2020-03-15  North America  Antigua and Barbuda          1.0
# 1           WLF  2020-11-14        Oceania    Wallis and Futuna          1.0
# 2           WLF  2020-11-15        Oceania    Wallis and Futuna          1.0
# 3           WLF  2020-11-16        Oceania    Wallis and Futuna          1.0
# 4           SMR  2020-02-28         Europe           San Marino          1.0
# ...         ...         ...            ...                  ...          ...
# 297147      ZWE  2020-03-16         Africa             Zimbabwe          NaN
# 297148      ZWE  2020-03-17         Africa             Zimbabwe          NaN
# 297149      ZWE  2020-03-18         Africa             Zimbabwe          NaN
# 297150      ZWE  2020-03-19         Africa             Zimbabwe          NaN
# 297151      ZWE  2020-03-20         Africa             Zimbabwe          NaN
#
#         new_cases  total_deaths  new_deaths  population  life_expectancy
# 0             1.0           NaN         0.0     93772.0            77.02
# 1             0.0           NaN         0.0     11596.0            79.94
# 2             0.0           NaN         0.0     11596.0            79.94
# 3             0.0           NaN         0.0     11596.0            79.94
# 4             1.0           NaN         0.0     33690.0            84.97
# ...           ...           ...         ...         ...              ...
# 297147        0.0           5.0         0.0  16320539.0            61.49
# 297148        0.0           5.0         0.0  16320539.0            61.49
# 297149        0.0           5.0         0.0  16320539.0            61.49
# 297150        0.0           5.0         0.0  16320539.0            61.49
# 297151        0.0           5.0         0.0  16320539.0            61.49
#
# [297152 rows x 10 columns]

# %% [markdown]
# ### Dimensionality Reduction

# %% [markdown]
# ### Data Reduction

# %%
for index in Main_Data['location'].value_counts().index:
    if len(Main_Data[Main_Data['location']==index]['total_cases'].unique())<2:
        print(index,end=" ")
        print(Main_Data[Main_Data['location']==index]['total_cases'].unique(),end=" ")
        print(len(Main_Data[Main_Data['location']==index]['total_cases'].unique()),end=" ")
        Main_Data=Main_Data[Main_Data['location']!=index]
# Out:
# North Korea [nan] 1 Turkmenistan [nan] 1 Taiwan [nan] 1 Hong Kong [nan] 1 Northern Ireland [nan] 1 Scotland [nan] 1 England [nan] 1 Wales [nan] 1 Macao [nan] 1 Northern Cyprus [nan] 1 Western Sahara [nan] 1

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### Handlling Missing Values

# %% [markdown]
# checking if any column has null values

# %% [markdown]
# checking counts of the null values of columns

# %%
Main_Data.isnull().any()
# Out:
# iso_code           False
# date               False
# continent           True
# location           False
# total_cases         True
# new_cases           True
# total_deaths        True
# new_deaths          True
# population         False
# life_expectancy     True
# dtype: bool

# %%
Main_Data.isnull().sum()
# Out:
# iso_code               0
# date                   0
# continent          14131
# location               0
# total_cases        25225
# new_cases            299
# total_deaths       45639
# new_deaths           233
# population             0
# life_expectancy    18822
# dtype: int64

# %% [markdown]
# #### Manual Handaling

# %% [markdown]
# ##### handling Null Values in Continent Column

# %%
Main_Data[
    Main_Data['continent'].isnull()
]['location'].value_counts()
# Out:
# Lower middle income    1179
# South America          1179
# Asia                   1179
# Upper middle income    1179
# High income            1179
# European Union         1179
# Europe                 1179
# World                  1179
# North America          1177
# Oceania                1174
# Africa                 1174
# Low income             1174
# Name: location, dtype: int64

# %%
Main_Data[Main_Data['continent'].isnull()==True]['location'].value_counts().index
# Out:
# Index(['Lower middle income', 'South America', 'Asia', 'Upper middle income',
#        'High income', 'European Union', 'Europe', 'World', 'North America',
#        'Oceania', 'Africa', 'Low income'],
#       dtype='object')

# %%
for index in Main_Data[Main_Data['continent'].isnull()==True]['location'].value_counts().index:
    if index.find("income")!=-1:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Income Based"})
    elif index.find("Europe")!=-1:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Europe"})
    elif index.find("International")!=-1 or index.find("World")!=-1:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"World"})
    else:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":index})

# %%
Main_Data[Main_Data['continent'].isnull()]['location'].value_counts()
# Out:
# Series([], Name: location, dtype: int64)

# %%
Main_Data['continent'].value_counts()
# Out:
# Africa           68092
# Europe           62304
# Asia             54033
# North America    49324
# Oceania          29352
# South America    17631
# Income Based      4711
# World             1179
# Name: continent, dtype: int64

# %%
Main_Data.isnull().sum()
# Out:
# iso_code               0
# date                   0
# continent              0
# location               0
# total_cases        25225
# new_cases            299
# total_deaths       45639
# new_deaths           233
# population             0
# life_expectancy    18822
# dtype: int64

# %% [markdown]
# #### handling Null Values in life_expectancy Column

# %%
Main_Data[Main_Data['life_expectancy'].isnull()]['continent'].value_counts()
# Out:
# Europe           5880
# Income Based     4711
# North America    2351
# Oceania          2348
# South America    1179
# Asia             1179
# Africa           1174
# Name: continent, dtype: int64

# %%
for index in Main_Data[Main_Data['life_expectancy'].isnull()==False]['continent'].value_counts().index:
    Main_Data[Main_Data['continent']==index]=Main_Data[Main_Data['continent']==index].fillna(value={"life_expectancy":Main_Data[Main_Data['continent']==index]['life_expectancy'].mean()})
Main_Data=Main_Data.fillna(value={"life_expectancy":Main_Data['life_expectancy'].mean()})

# %%
Main_Data[Main_Data['life_expectancy'].isnull()]['continent'].value_counts()
# Out:
# Series([], Name: continent, dtype: int64)

# %%
Main_Data['life_expectancy'].value_counts()
# Out:
# 79.779720    5880
# 73.777894    4711
# 76.880000    3522
# 72.580000    2358
# 75.050000    2353
#              ...
# 82.430000    1174
# 83.920000    1174
# 82.050000    1174
# 68.370000    1174
# 71.680000    1173
# Name: life_expectancy, Length: 221, dtype: int64

# %%
Main_Data.isnull().sum()
# Out:
# iso_code               0
# date                   0
# continent              0
# location               0
# total_cases        25225
# new_cases            299
# total_deaths       45639
# new_deaths           233
# population             0
# life_expectancy        0
# dtype: int64

# %% [markdown]
# #### handling Null Values in Population Column

# %%
Main_Data[Main_Data['population'].isnull()==True]['location'].value_counts()
# Out:
# Series([], Name: location, dtype: int64)

# %%
Main_Data['population']=Main_Data['population'].fillna(Main_Data[Main_Data['location']=='International']['total_cases'].max())

# %%
Main_Data[Main_Data['population'].isnull()==True]['location'].value_counts()
# Out:
# Series([], Name: location, dtype: int64)

# %%
Main_Data.isnull().sum()
# Out:
# iso_code               0
# date                   0
# continent              0
# location               0
# total_cases        25225
# new_cases            299
# total_deaths       45639
# new_deaths           233
# population             0
# life_expectancy        0
# dtype: int64

# %% [markdown]
# #### Multiple Columns Null Values Handlling

# %% [markdown]
# ##### handling Null Values in new_cases and new_deaths Column

# %%
Main_Data[['new_cases','new_deaths']]=Main_Data[['new_cases','new_deaths']].fillna(0)

# %%
Main_Data.isnull().sum()
# Out:
# iso_code               0
# date                   0
# continent              0
# location               0
# total_cases        25225
# new_cases              0
# total_deaths       45639
# new_deaths             0
# population             0
# life_expectancy        0
# dtype: int64

# %% [markdown]
# ##### handling Null Values in total_cases and total_deaths Column

# %%
for index in Main_Data['location'].value_counts().index:
    Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(0,limit=1)
    Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(method='ffill')

# %%
Main_Data.isnull().sum()
# Out:
# iso_code           0
# date               0
# continent          0
# location           0
# total_cases        0
# new_cases          0
# total_deaths       0
# new_deaths         0
# population         0
# life_expectancy    0
# dtype: int64

# %%
Main_Data
# Out:
#        iso_code        date      continent             location  total_cases  \
# 0           ATG  2020-03-15  North America  Antigua and Barbuda          1.0
# 1           WLF  2020-11-14        Oceania    Wallis and Futuna          1.0
# 2           WLF  2020-11-15        Oceania    Wallis and Futuna          1.0
# 3           WLF  2020-11-16        Oceania    Wallis and Futuna          1.0
# 4           SMR  2020-02-28         Europe           San Marino          1.0
# ...         ...         ...            ...                  ...          ...
# 297147      ZWE  2020-03-16         Africa             Zimbabwe          0.0
# 297148      ZWE  2020-03-17         Africa             Zimbabwe          0.0
# 297149      ZWE  2020-03-18         Africa             Zimbabwe          0.0
# 297150      ZWE  2020-03-19         Africa             Zimbabwe          0.0
# 297151      ZWE  2020-03-20         Africa             Zimbabwe          0.0
#
#         new_cases  total_deaths  new_deaths  population  life_expectancy
# 0             1.0           0.0         0.0     93772.0            77.02
# 1             0.0           0.0         0.0     11596.0            79.94
# 2             0.0           0.0         0.0     11596.0            79.94
# 3             0.0           0.0         0.0     11596.0            79.94
# 4             1.0           0.0         0.0     33690.0            84.97
# ...           ...           ...         ...         ...              ...
# 297147        0.0           5.0         0.0  16320539.0            61.49
# 297148        0.0           5.0         0.0  16320539.0            61.49
# 297149        0.0           5.0         0.0  16320539.0            61.49
# 297150        0.0           5.0         0.0  16320539.0            61.49
# 297151        0.0           5.0         0.0  16320539.0            61.49
#
# [286626 rows x 10 columns]

# %% [markdown]
# ## Final Function for Whole Data Processing for Covid Data

# %%
def PreprocessTheCovidData(Main_Data,Selected_columns)->pandas.DataFrame:
    Main_Data=Main_Data[Selected_Columns]
    for index in Main_Data['location'].value_counts().index:
        if len(Main_Data[Main_Data['location']==index]['total_cases'].unique())<2:
            Main_Data=Main_Data[Main_Data['location']!=index]
    for index in Main_Data[Main_Data['continent'].isnull()==True]['location'].value_counts().index:
        if index.find("income")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Income Based"})
        elif index.find("Europe")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"Europe"})
        elif index.find("International")!=-1 or index.find("World")!=-1:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":"World"})
        else:
            Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(value={"continent":index})
    for index in Main_Data[Main_Data['life_expectancy'].isnull()==False]['continent'].value_counts().index:
        Main_Data[Main_Data['continent']==index]=Main_Data[Main_Data['continent']==index].fillna(value={"life_expectancy":Main_Data[Main_Data['continent']==index]['life_expectancy'].mean()})
    Main_Data=Main_Data.fillna(value={"life_expectancy":Main_Data['life_expectancy'].mean()})
    Main_Data['population']=Main_Data['population'].fillna(Main_Data[Main_Data['location']=='International']['total_cases'].max())
    Main_Data[['new_cases','new_deaths']]=Main_Data[['new_cases','new_deaths']].fillna(0)
    for index in Main_Data['location'].value_counts().index:
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(0,limit=1)
        Main_Data[Main_Data['location']==index]=Main_Data[Main_Data['location']==index].fillna(method='ffill')
    return Main_Data

# %%
PreprocessTheCovidData(Raw_Data.copy().reset_index(drop=True),Selected_Columns)
# Out:
# Northern Ireland [nan] 1 Scotland [nan] 1 England [nan] 1 Wales [nan] 1 Puerto Rico [nan] 1 Guam [nan] 1 United States Virgin Islands [nan] 1 Northern Cyprus [nan] 1 Guernsey [nan] 1 Jersey [nan] 1 Turkmenistan [nan] 1 Northern Mariana Islands [nan] 1 Sint Maarten (Dutch part) [nan] 1 Tokelau [nan] 1 Niue [nan] 1 Pitcairn [nan] 1 Western Sahara [nan] 1
# iso_code           0
# date               0
# continent          0
# location           0
# total_cases        0
# new_cases          0
# total_deaths       0
# new_deaths         0
# population         0
# life_expectancy    0
# dtype: int64
#        iso_code        date continent              location  total_cases  \
# 0           FSM  2021-07-29   Oceania  Micronesia (country)          1.0
# 1           PRK  2022-06-22      Asia           North Korea          1.0
# 2           PRK  2022-06-26      Asia           North Korea          1.0
# 3           PRK  2022-06-27      Asia           North Korea          1.0
# 4           PRK  2022-06-28      Asia           North Korea          1.0
# ...         ...         ...       ...                   ...          ...
# 255139      TUV  2022-05-19   Oceania                Tuvalu          0.0
# 255140      TUV  2022-05-20   Oceania                Tuvalu          0.0
# 255141      TUV  2022-05-21   Oceania                Tuvalu          0.0
# 255142      TUV  2022-05-22   Oceania                Tuvalu          0.0
# 255143      GBR  2020-01-30    Europe        United Kingdom          0.0
#
#         new_cases  total_deaths  new_deaths  population  life_expectancy
# 0             0.0           0.0         0.0    114178.0            67.88
# 1             0.0           6.0         0.0  26069416.0            72.27
# 2             0.0           6.0         0.0  26069416.0            72.27
# 3             0.0           6.0         0.0  26069416.0            72.27
# 4             0.0           6.0         0.0  26069416.0            72.27
# ...           ...           ...         ...         ...              ...
# 255139        0.0           0.0         0.0     11335.0            67.57
# 255140        0.0           0.0         0.0     11335.0            67.57
# 255141        0.0           0.0         0.0     11335.0            67.57
# 255142        0.0           0.0         0.0     11335.0            67.57
# 255143        0.0           1.0         1.0  67508936.0            81.32
#
# [244875 rows x 10 columns]

# %% [markdown]
# ## Data Integration

# %%
India_Data=PreprocessTheCovidData(
    Main_Data=Main_Data[
        Main_Data['location']=='India'
    ].copy().reset_index(drop=True),
    Selected_columns=Selected_Columns
)

# %%
Japan_Data=PreprocessTheCovidData(
    Main_Data=Main_Data[
        Main_Data['location']=='Japan'
    ].copy().reset_index(drop=True),
    Selected_columns=Selected_Columns
)

# %%
Australia_Data=PreprocessTheCovidData(
    Main_Data=Main_Data[
    Main_Data['location']=='Australia'
    ].copy().reset_index(drop=True),
    Selected_columns=Selected_Columns
)

# %%
Specific_locations_Data=pandas.concat(
    [
        India_Data,
        Japan_Data,
        Australia_Data
    ],
    ignore_index=True
)

# %%
Specific_locations_Data
# Out:
#      iso_code        date continent   location  total_cases  new_cases  \
# 0         IND  2020-01-31      Asia      India          1.0        0.0
# 1         IND  2020-02-01      Asia      India          1.0        0.0
# 2         IND  2020-01-30      Asia      India          1.0        1.0
# 3         IND  2020-02-02      Asia      India          2.0        1.0
# 4         IND  2020-02-15      Asia      India          3.0        0.0
# ...       ...         ...       ...        ...          ...        ...
# 3337      AUS  2023-02-02   Oceania  Australia   11313123.0    17677.0
# 3338      AUS  2023-02-09   Oceania  Australia   11327900.0    14996.0
# 3339      AUS  2023-02-12   Oceania  Australia   11330342.0        0.0
# 3340      AUS  2023-02-11   Oceania  Australia   11330342.0        0.0
# 3341      AUS  2023-02-10   Oceania  Australia   11330342.0     2442.0
#
#       total_deaths  new_deaths    population  life_expectancy
# 0              0.0         0.0  1.417173e+09            69.66
# 1              0.0         0.0  1.417173e+09            69.66
# 2              0.0         0.0  1.417173e+09            69.66
# 3              0.0         0.0  1.417173e+09            69.66
# 4              0.0         0.0  1.417173e+09            69.66
# ...            ...         ...           ...              ...
# 3337       18828.0       213.0  2.617741e+07            83.44
# 3338       19063.0       235.0  2.617741e+07            83.44
# 3339       19070.0         0.0  2.617741e+07            83.44
# 3340       19070.0         0.0  2.617741e+07            83.44
# 3341       19070.0         7.0  2.617741e+07            83.44
#
# [3342 rows x 10 columns]

# %%
India_Data.merge(Japan_Data,on='continent')
# Out:
#         iso_code_x      date_x continent location_x  total_cases_x  \
# 0              IND  2020-01-31      Asia      India            1.0
# 1              IND  2020-01-31      Asia      India            1.0
# 2              IND  2020-01-31      Asia      India            1.0
# 3              IND  2020-01-31      Asia      India            1.0
# 4              IND  2020-01-31      Asia      India            1.0
# ...            ...         ...       ...        ...            ...
# 1240975        IND  2023-02-12      Asia      India     44685425.0
# 1240976        IND  2023-02-12      Asia      India     44685425.0
# 1240977        IND  2023-02-12      Asia      India     44685425.0
# 1240978        IND  2023-02-12      Asia      India     44685425.0
# 1240979        IND  2023-02-12      Asia      India     44685425.0
#
#          new_cases_x  total_deaths_x  new_deaths_x  population_x  \
# 0                0.0             0.0           0.0  1.417173e+09
# 1                0.0             0.0           0.0  1.417173e+09
# 2                0.0             0.0           0.0  1.417173e+09
# 3                0.0             0.0           0.0  1.417173e+09
# 4                0.0             0.0           0.0  1.417173e+09
# ...              ...             ...           ...           ...
# 1240975        206.0        530753.0           3.0  1.417173e+09
# 1240976        206.0        530753.0           3.0  1.417173e+09
# 1240977        206.0        530753.0           3.0  1.417173e+09
# 1240978        206.0        530753.0           3.0  1.417173e+09
# 1240979        206.0        530753.0           3.0  1.417173e+09
#
#          life_expectancy_x iso_code_y      date_y location_y  total_cases_y  \
# 0                    69.66        JPN  2020-01-23      Japan            2.0
# 1                    69.66        JPN  2020-01-25      Japan            2.0
# 2                    69.66        JPN  2020-01-24      Japan            2.0
# 3                    69.66        JPN  2020-01-22      Japan            2.0
# 4                    69.66        JPN  2020-01-26      Japan            4.0
# ...                    ...        ...         ...        ...            ...
# 1240975              69.66        JPN  2023-02-08      Japan     32868798.0
# 1240976              69.66        JPN  2023-02-09      Japan     32901767.0
# 1240977              69.66        JPN  2023-02-10      Japan     32930382.0
# 1240978              69.66        JPN  2023-02-11      Japan     32957753.0
# 1240979              69.66        JPN  2023-02-12      Japan     32971493.0
#
#          new_cases_y  total_deaths_y  new_deaths_y  population_y  \
# 0                0.0             0.0           0.0   123951696.0
# 1                0.0             0.0           0.0   123951696.0
# 2                0.0             0.0           0.0   123951696.0
# 3                0.0             0.0           0.0   123951696.0
# 4                2.0             0.0           0.0   123951696.0
# ...              ...             ...           ...           ...
# 1240975      41584.0         69970.0         200.0   123951696.0
# 1240976      32969.0         70193.0         223.0   123951696.0
# 1240977      28615.0         70385.0         192.0   123951696.0
# 1240978      27371.0         70566.0         181.0   123951696.0
# 1240979      13740.0         70703.0         137.0   123951696.0
#
#          life_expectancy_y
# 0                    84.63
# 1                    84.63
# 2                    84.63
# 3                    84.63
# 4                    84.63
# ...                    ...
# 1240975              84.63
# 1240976              84.63
# 1240977              84.63
# 1240978              84.63
# 1240979              84.63
#
# [1240980 rows x 19 columns]

# %%
India_Data.merge(Japan_Data,on='date',how="left")
# Out:
#      iso_code_x        date continent_x location_x  total_cases_x  \
# 0           IND  2020-01-31        Asia      India            1.0
# 1           IND  2020-02-01        Asia      India            1.0
# 2           IND  2020-01-30        Asia      India            1.0
# 3           IND  2020-02-02        Asia      India            2.0
# 4           IND  2020-02-15        Asia      India            3.0
# ...         ...         ...         ...        ...            ...
# 1105        IND  2023-02-07        Asia      India     44684864.0
# 1106        IND  2023-02-08        Asia      India     44684973.0
# 1107        IND  2023-02-09        Asia      India     44685087.0
# 1108        IND  2023-02-11        Asia      India     44685219.0
# 1109        IND  2023-02-12        Asia      India     44685425.0
#
#       new_cases_x  total_deaths_x  new_deaths_x  population_x  \
# 0             0.0             0.0           0.0  1.417173e+09
# 1             0.0             0.0           0.0  1.417173e+09
# 2             1.0             0.0           0.0  1.417173e+09
# 3             1.0             0.0           0.0  1.417173e+09
# 4             0.0             0.0           0.0  1.417173e+09
# ...           ...             ...           ...           ...
# 1105         96.0        530746.0           1.0  1.417173e+09
# 1106        109.0        530748.0           2.0  1.417173e+09
# 1107        114.0        530750.0           2.0  1.417173e+09
# 1108       1357.0        530750.0           0.0  1.417173e+09
# 1109        206.0        530753.0           3.0  1.417173e+09
#
#       life_expectancy_x iso_code_y continent_y location_y  total_cases_y  \
# 0                 69.66        JPN        Asia      Japan           15.0
# 1                 69.66        JPN        Asia      Japan           20.0
# 2                 69.66        JPN        Asia      Japan           11.0
# 3                 69.66        JPN        Asia      Japan           20.0
# 4                 69.66        JPN        Asia      Japan           54.0
# ...                 ...        ...         ...        ...            ...
# 1105              69.66        JPN        Asia      Japan     32827214.0
# 1106              69.66        JPN        Asia      Japan     32868798.0
# 1107              69.66        JPN        Asia      Japan     32901767.0
# 1108              69.66        JPN        Asia      Japan     32957753.0
# 1109              69.66        JPN        Asia      Japan     32971493.0
#
#       new_cases_y  total_deaths_y  new_deaths_y  population_y  \
# 0             4.0             0.0           0.0   123951696.0
# 1             5.0             0.0           0.0   123951696.0
# 2             4.0             0.0           0.0   123951696.0
# 3             0.0             0.0           0.0   123951696.0
# 4            11.0             1.0           0.0   123951696.0
# ...           ...             ...           ...           ...
# 1105      44755.0         69770.0         161.0   123951696.0
# 1106      41584.0         69970.0         200.0   123951696.0
# 1107      32969.0         70193.0         223.0   123951696.0
# 1108      27371.0         70566.0         181.0   123951696.0
# 1109      13740.0         70703.0         137.0   123951696.0
#
#       life_expectancy_y
# 0                 84.63
# 1                 84.63
# 2                 84.63
# 3                 84.63
# 4                 84.63
# ...                 ...
# 1105              84.63
# 1106              84.63
# 1107              84.63
# 1108              84.63
# 1109              84.63
#
# [1110 rows x 19 columns]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### 1.  Attribution

# %% [markdown]
# #### creating new Attribute death_percentage on new cases

# %%
India_Data['death_percentage_for_new_cases']=[100*i[1]/max(1,i[0]) for  i in India_Data[['new_cases','new_deaths']].to_numpy()]

# %%
India_Data
# Out:
#      iso_code        date continent location  total_cases  new_cases  \
# 0         IND  2020-01-31      Asia    India          1.0        0.0
# 1         IND  2020-02-01      Asia    India          1.0        0.0
# 2         IND  2020-01-30      Asia    India          1.0        1.0
# 3         IND  2020-02-02      Asia    India          2.0        1.0
# 4         IND  2020-02-15      Asia    India          3.0        0.0
# ...       ...         ...       ...      ...          ...        ...
# 1105      IND  2023-02-07      Asia    India   44684864.0       96.0
# 1106      IND  2023-02-08      Asia    India   44684973.0      109.0
# 1107      IND  2023-02-09      Asia    India   44685087.0      114.0
# 1108      IND  2023-02-11      Asia    India   44685219.0     1357.0
# 1109      IND  2023-02-12      Asia    India   44685425.0      206.0
#
#       total_deaths  new_deaths    population  life_expectancy  \
# 0              0.0         0.0  1.417173e+09            69.66
# 1              0.0         0.0  1.417173e+09            69.66
# 2              0.0         0.0  1.417173e+09            69.66
# 3              0.0         0.0  1.417173e+09            69.66
# 4              0.0         0.0  1.417173e+09            69.66
# ...            ...         ...           ...              ...
# 1105      530746.0         1.0  1.417173e+09            69.66
# 1106      530748.0         2.0  1.417173e+09            69.66
# 1107      530750.0         2.0  1.417173e+09            69.66
# 1108      530750.0         0.0  1.417173e+09            69.66
# 1109      530753.0         3.0  1.417173e+09            69.66
#
#       death_percentage_for_new_cases
# 0                           0.000000
# 1                           0.000000
# 2                           0.000000
# 3                           0.000000
# 4                           0.000000
# ...                              ...
# 1105                        1.041667
# 1106                        1.834862
# 1107                        1.754386
# 1108                        0.000000
# 1109                        1.456311
#
# [1110 rows x 11 columns]

# %% [markdown]
# ### 2. Normalization

# %%
Normalizer.fit_transform([India_Data['total_cases'],India_Data['total_deaths']])
# Out:
# array([[2.23786615e-08, 2.23786615e-08, 2.23786615e-08, ...,
#         9.99992436e-01, 9.99995390e-01, 1.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         9.99994348e-01, 9.99994348e-01, 1.00000000e+00]])

# %% [markdown]
# ### 3. Standardization

# %%
StandardScaler.fit_transform([India_Data['total_cases']])
# Out:
# array([[1.0000000e+00, 1.0000000e+00, 1.0000000e+00, ..., 4.4685087e+07,
#         4.4685219e+07, 4.4685425e+07]])
